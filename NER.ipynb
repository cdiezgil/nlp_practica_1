# %% [markdown]
# **Universidad Internacional de La Rioja (UNIR) - Máster Universitario en Inteligencia Artificial - Procesamiento del Lenguaje Natural**

# %% [markdown]
# ***
# Datos del alumno (Nombre y Apellidos): Carlos Díez-Gil Romero
#
# Fecha: 12-04-2023
# ***

# %% [markdown]
# <span style="font-size: 20pt; font-weight: bold; color: #0098cd;">Trabajo: Named-Entity Recognition</span>
#
# **Objetivos**
#
# Con esta actividad se tratará de que el alumno se familiarice con el manejo de la librería spacy, así como con los conceptos básicos de manejo de las técnicas NER
#
# **Descripción**
#
# En esta actividad debes procesar de forma automática un texto en lenguaje natural para detectar características básicas en el mismo, y para identificar y etiquetar las ocurrencias de conceptos como localización, moneda, empresas, etc.
#
# En la primera parte del ejercicio se proporciona un código fuente a través del cual se lee un archivo de texto y se realiza un preprocesado del mismo. En esta parte el alumno tan sólo debe ejecutar y entender el código proporcionado.
#
# En la segunda parte del ejercicio se plantean una serie de preguntas que deben ser respondidas por el alumno. Cada pregunta deberá responderse con un fragmento de código fuente que esté acompañado de la explicación correspondiente. Para elaborar el código solicitado, el alumno deberá visitar la documentación de la librería spacy, cuyos enlaces se proporcionarán donde corresponda.

# %% [markdown]
# # Parte 1: carga y preprocesamiento del texto a analizar

# %% [markdown]
# Observa las diferentes librerías que se están importando.

# %%
import pathlib
import spacy
from spacy import displacy
import en_core_web_sm

# %% [markdown]
# El siguiente código simplemente carga y preprocesa el texto. Para ello, lo primero que hace es cargar un modelo de lenguaje previamente entrenado. En este caso, se utiliza <i>en_core_web_sm</i>:
#
# https://spacy.io/models/en#en_core_web_sm
#
# Al cargar el modelo de lenguaje se genera un <i>Pipeline</i>, que nos permite realizar las diferentes tareas. En este caso, vamos a utilizar el pipeline para hacer un preprocesamiento básico, que consiste en tokenizar el texto.
#
# Al final del código proporcionado <i>doc</i> representa una versión tokenizada del texto leído.

# %%
nlp = en_core_web_sm.load()
file_name = "barack-obama-speech.txt"
doc = nlp(pathlib.Path(file_name).read_text(encoding="utf-8"))

# %% [markdown]
# ### Playground
#
# La variable <i>doc</i> es un objeto de la clase <i>Doc</i> (https://spacy.io/api/doc)
#
# Visita la documentación de dicha clase y experimenta probando las diferentes funciones y atributos

# %%
print(max([s for s in doc.sents], key=len))

lemmas = [token.lemma_ for token in doc]
print(lemmas)

lexema = [token.lex for token in doc]
# Out:
# It drew strength from the not-so-young people who braved the bitter cold and scorching heat to knock on doors of perfect strangers, and from the millions of Americans who volunteered and organized and proved that more than two centuries later a government of the people, by the people, and for the people has not perished from the Earth.
#
# ['"', 'Hello', ',', 'Chicago', '.', '\n', 'if', 'there', 'be', 'anyone', 'out', 'there', 'who', 'still', 'doubt', 'that', 'America', 'be', 'a', 'place', 'where', 'all', 'thing', 'be', 'possible', ',', 'who', 'still', 'wonder', 'if', 'the', 'dream', 'of', 'our', 'founder', 'be', 'alive', 'in', 'our', 'time', ',', 'who', 'still', 'question', 'the', 'power', 'of', 'our', 'democracy', ',', 'tonight', 'be', 'your', 'answer', '.', '\n', 'it', '’', 'the', 'answer', 'tell', 'by', 'line', 'that', 'stretch', 'around', 'school', 'and', 'church', 'in', 'number', 'this', 'nation', 'have', 'never', 'see', ',', 'by', 'people', 'who', 'wait', 'three', 'hour', 'and', 'four', 'hour', ',', 'many', 'for', 'the', 'first', 'time', 'in', 'their', 'life', ',', 'because', 'they', 'believe', 'that', 'this', 'time', 'must', 'be', 'different', ',', 'that', 'their', 'voice', 'could', 'be', 'that', 'difference', '.', '\n', 'it', '’', 'the', 'answer', 'speak', 'by', 'young', 'and', 'old', ',', 'rich', 'and', 'poor', ',', 'Democrat', 'and', 'Republican', ',', 'black', ',', 'white', ',', 'hispanic', ',', 'asian', ',', 'Native', 'American', ',', 'gay', ',', 'straight', ',', 'disabled', 'and', 'not', 'disabled', '.', 'american', 'who', 'send', 'a', 'message', 'to', 'the', 'world', 'that', 'we', 'have', 'never', 'be', 'just', 'a', 'collection', 'of', 'individual', 'or', 'a', 'collection', 'of', 'red', 'state', 'and', 'blue', 'state', '.', '\n', 'we', 'be', ',', 'and', 'always', 'will', 'be', ',', 'the', 'United', 'States', 'of', 'America', '.', '\n', 'it', '’', 'the', 'answer', 'that', 'lead', 'those', 'who', '’ve', 'been', 'tell', 'for', 'so', 'long', 'by', 'so', 'many', 'to', 'be', 'cynical', 'and', 'fearful', 'and', 'doubtful', 'about', 'what', 'we', 'can', 'achieve', 'to', 'put', 'their', 'hand', 'on', 'the', 'arc', 'of', 'history', 'and', 'bend', 'it', 'once', 'more', 'toward', 'the', 'hope', 'of', 'a', 'well', 'day', '.', '\n', 'it', '’s', 'be', 'a', 'long', 'time', 'come', ',', 'but', 'tonight', ',', 'because', 'of', 'what', 'we', 'do', 'on', 'this', 'date', 'in', 'this', 'election', 'at', 'this', 'define', 'moment', 'change', 'have', 'come', 'to', 'America', '.', '\n', '[', 'read', 'more', ']', '\n\n', 'we', 'do', 'not', 'start', 'with', 'much', 'money', 'or', 'many', 'endorsement', '.', 'our', 'campaign', 'be', 'not', 'hatch', 'in', 'the', 'hall', 'of', 'Washington', '.', 'it', 'begin', 'in', 'the', 'backyard', 'of', 'Des', 'Moines', 'and', 'the', 'live', 'room', 'of', 'Concord', 'and', 'the', 'front', 'porch', 'of', 'Charleston', '.', 'it', 'be', 'build', 'by', 'work', 'man', 'and', 'woman', 'who', 'dig', 'into', 'what', 'little', 'saving', 'they', 'have', 'to', 'give', '$', '5', 'and', '$', '10', 'and', '$', '20', 'to', 'the', 'cause', '.', '\n', 'it', 'grow', 'strength', 'from', 'the', 'young', 'people', 'who', 'reject', 'the', 'myth', 'of', 'their', 'generation', '’s', 'apathy', 'who', 'leave', 'their', 'home', 'and', 'their', 'family', 'for', 'job', 'that', 'offer', 'little', 'pay', 'and', 'less', 'sleep', '.', '\n', 'it', 'draw', 'strength', 'from', 'the', 'not', '-', 'so', '-', 'young', 'people', 'who', 'brave', 'the', 'bitter', 'cold', 'and', 'scorch', 'heat', 'to', 'knock', 'on', 'door', 'of', 'perfect', 'stranger', ',', 'and', 'from', 'the', 'million', 'of', 'Americans', 'who', 'volunteer', 'and', 'organize', 'and', 'prove', 'that', 'more', 'than', 'two', 'century', 'later', 'a', 'government', 'of', 'the', 'people', ',', 'by', 'the', 'people', ',', 'and', 'for', 'the', 'people', 'have', 'not', 'perish', 'from', 'the', 'Earth', '.', '\n', 'this', 'be', 'your', 'victory', '.', '\n', 'and', 'I', 'know', 'you', 'do', 'not', 'do', 'this', 'just', 'to', 'win', 'an', 'election', '.', 'and', 'I', 'know', 'you', 'do', 'not', 'do', 'it', 'for', 'I', '.', '\n', 'you', 'do', 'it', 'because', 'you', 'understand', 'the', 'enormity', 'of', 'the', 'task', 'that', 'lie', 'ahead', '.', 'for', 'even', 'as', 'we', 'celebrate', 'tonight', ',', 'we', 'know', 'the', ...

# %% [markdown]
# # Parte 2: preguntas

# %% [markdown]
# Para responder a cada una de las preguntas planteadas deberás aportar tanto el código fuente con el cual puedes conseguir la respuesta, como una explicación válida de la respuesta y de la forma de obtenerla.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 1.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Cuántas palabras tiene el texto?</span>

# %%
# Incluye aquí el código generado para poder responder a tu pregunta
print(len(doc))
# Out:
# 1939

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>
#
# Dentro de la variable doc se encuentran todos los tokens del texto, por lo que para obtener el número de palabras del texto se puede utilizar la función len() sobre doc.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 2.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Cuántas oraciones tiene el texto?</span>

# %%
# Incluye aquí el código generado para poder responder a tu pregunta
print(len(list(doc.sents)))
# Out:
# 83

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>
#
# doc.sents es una lista de oraciones, por lo que para obtener el número de oraciones del texto se puede utilizar la función len() sobre doc.sents.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 3.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Cuál el número de palabras de la oración más grande? ¿Cual es dicha oración?</span>

# %%
print(max([len(s) for s in doc.sents]))
print(max([s for s in doc.sents], key=len))
# Out:
# 67
# It drew strength from the not-so-young people who braved the bitter cold and scorching heat to knock on doors of perfect strangers, and from the millions of Americans who volunteered and organized and proved that more than two centuries later a government of the people, by the people, and for the people has not perished from the Earth.

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>
#
# Dentro de doc.sents se encuentran todas las oraciones del texto, por lo que para obtener la oración más grande se puede utilizar la función max() sobre doc.sents, pasando como parámetro la función len() para obtener el número de palabras de cada oración.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 4.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Cómo puedes acceder al lema, lexema y morfemas de cada token?</span>
#
# Recomendación: si no lo has hecho ya, visita la documentación de la clase <i>Token</i>: https://spacy.io/api/token

# %%
for idx, token in enumerate (doc):
    print ("Lexema: " + token.lex.text +" Lema: " + token.lemma_ + " Morfema: " + token.suffix_)
# Out:
# Lexema: “ Lema: " Morfema: “
# Lexema: Hello Lema: Hello Morfema: llo
# Lexema: , Lema: , Morfema: ,
# Lexema: Chicago Lema: Chicago Morfema: ago
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: If Lema: if Morfema: If
# Lexema: there Lema: there Morfema: ere
# Lexema: is Lema: be Morfema: is
# Lexema: anyone Lema: anyone Morfema: one
# Lexema: out Lema: out Morfema: out
# Lexema: there Lema: there Morfema: ere
# Lexema: who Lema: who Morfema: who
# Lexema: still Lema: still Morfema: ill
# Lexema: doubts Lema: doubt Morfema: bts
# Lexema: that Lema: that Morfema: hat
# Lexema: America Lema: America Morfema: ica
# Lexema: is Lema: be Morfema: is
# Lexema: a Lema: a Morfema: a
# Lexema: place Lema: place Morfema: ace
# Lexema: where Lema: where Morfema: ere
# Lexema: all Lema: all Morfema: all
# Lexema: things Lema: thing Morfema: ngs
# Lexema: are Lema: be Morfema: are
# Lexema: possible Lema: possible Morfema: ble
# Lexema: , Lema: , Morfema: ,
# Lexema: who Lema: who Morfema: who
# Lexema: still Lema: still Morfema: ill
# Lexema: wonders Lema: wonder Morfema: ers
# Lexema: if Lema: if Morfema: if
# Lexema: the Lema: the Morfema: the
# Lexema: dream Lema: dream Morfema: eam
# Lexema: of Lema: of Morfema: of
# Lexema: our Lema: our Morfema: our
# Lexema: founders Lema: founder Morfema: ers
# Lexema: is Lema: be Morfema: is
# Lexema: alive Lema: alive Morfema: ive
# Lexema: in Lema: in Morfema: in
# Lexema: our Lema: our Morfema: our
# Lexema: time Lema: time Morfema: ime
# Lexema: , Lema: , Morfema: ,
# Lexema: who Lema: who Morfema: who
# Lexema: still Lema: still Morfema: ill
# Lexema: questions Lema: question Morfema: ons
# Lexema: the Lema: the Morfema: the
# Lexema: power Lema: power Morfema: wer
# Lexema: of Lema: of Morfema: of
# Lexema: our Lema: our Morfema: our
# Lexema: democracy Lema: democracy Morfema: acy
# Lexema: , Lema: , Morfema: ,
# Lexema: tonight Lema: tonight Morfema: ght
# Lexema: is Lema: be Morfema: is
# Lexema: your Lema: your Morfema: our
# Lexema: answer Lema: answer Morfema: wer
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: It Lema: it Morfema: It
# Lexema: ’s Lema: ’ Morfema: ’s
# Lexema: the Lema: the Morfema: the
# Lexema: answer Lema: answer Morfema: wer
# Lexema: told Lema: tell Morfema: old
# Lexema: by Lema: by Morfema: by
# Lexema: lines Lema: line Morfema: nes
# Lexema: that Lema: that Morfema: hat
# Lexema: stretched Lema: stretch Morfema: hed
# Lexema: around Lema: around Morfema: und
# Lexema: schools Lema: school Morfema: ols
# Lexema: and Lema: and Morfema: and
# Lexema: churches Lema: church Morfema: hes
# Lexema: in Lema: in Morfema: in
# Lexema: numbers Lema: number Morfema: ers
# Lexema: this Lema: this Morfema: his
# Lexema: nation Lema: nation Morfema: ion
# Lexema: has Lema: have Morfema: has
# Lexema: never Lema: never Morfema: ver
# Lexema: seen Lema: see Morfema: een
# Lexema: , Lema: , Morfema: ,
# Lexema: by Lema: by Morfema: by
# Lexema: people Lema: people Morfema: ple
# Lexema: who Lema: who Morfema: who
# Lexema: waited Lema: wait Morfema: ted
# Lexema: three Lema: three Morfema: ree
# Lexema: hours Lema: hour Morfema: urs
# Lexema: and Lema: and Morfema: and
# Lexema: four Lema: four Morfema: our
# Lexema: hours Lema: hour Morfema: urs
# Lexema: , Lema: , Morfema: ,
# Lexema: many Lema: many Morfema: any
# Lexema: for Lema: for Morfema: for
# Lexema: the Lema: the Morfema: the
# Lexema: first Lema: first Morfema: rst
# Lexema: time Lema: time Morfema: ime
# Lexema: in Lema: in Morfema: in
# Lexema: their Lema: their Morfema: eir
# Lexema: lives Lema: life Morfema: ves
# Lexema: , Lema: , Morfema: ,
# Lexema: because Lema: because Morfema: use
# Lexema: they Lema: they Morfema: hey
# Lexema: believed Lema: believe Morfema: ved
# Lexema: that Lema: that Morfema: hat
# Lexema: this Lema: this Morfema: his
# Lexema: time Lema: time Morfema: ime
# Lexema: must Lema: must Morfema: ust
# Lexema: be Lema: be Morfema: be
# Lexema: different Lema: different Morfema: ent
# Lexema: , Lema: , Morfema: ,
# Lexema: that Lema: that Morfema: hat
# Lexema: their Lema: their Morfema: eir
# Lexema: voices Lema: voice Morfema: ces
# Lexema: could Lema: could Morfema: uld
# Lexema: be Lema: be Morfema: be
# Lexema: that Lema: that Morfema: hat
# Lexema: difference Lema: difference Morfema: nce
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: It Lema: it Morfema: It
# Lexema: ’s Lema: ’ Morfema: ’s
# Lexema: the Lema: the Morfema: the
# Lexema: answer Lema: answer Morfema: wer
# Lexema: spoken Lema: speak Morfema: ken
# Lexema: by Lema: by Morfema: by
# Lexema: young Lema: young Morfema: ung
# Lexema: and Lema: and Morfema: and
# Lexema: old Lema: old Morfema: old
# Lexema: , Lema: , Morfema: ,
# Lexema: rich Lema: rich Morfema: ich
# Lexema: and Lema: and Morfema: and
# Lexema: poor Lema: poor Morfema: oor
# Lexema: , Lema: , Morfema: ,
# Lexema: Democrat Lema: Democrat Morfema: rat
# Lexema: and Lema: and Morfema: and
# Lexema: Republican Lema: Republican Morfema: can
# Lexema: , Lema: , Morfema: ,
# Lexema: black Lema: black Morfema: ack
# Lexema: , Lema: , Morfema: ,
# Lexema: white Lema: white Morfema: ite
# Lexema: , Lema: , Morfema: ,
# Lexema: Hispanic Lema: hispanic Morfema: nic
# Lexema: , Lema: , Morfema: ,
# Lexema: Asian Lema: asian Morfema: ian
# Lexema: , Lema: , Morfema: ,
# Lexema: Native Lema: Native Morfema: ive
# Lexema: American Lema: American Morfema: can
# Lexema: , Lema: , Morfema: ,
# Lexema: gay Lema: gay Morfema: gay
# Lexema: , Lema: , Morfema: ,
# Lexema: straight Lema: straight Morfema: ght
# Lexema: , Lema: , Morfema: ,
# Lexema: disabled Lema: disabled Morfema: led
# Lexema: and Lema: and Morfema: and
# Lexema: not Lema: not Morfema: not
# Lexema: disabled Lema: disabled Morfema: led
# Lexema: . Lema: . Morfema: .
# Lexema: Americans Lema: american Morfema: ans
# Lexema: who Lema: who Morfema: who
# Lexema: sent Lema: send Morfema: ent
# Lexema: a Lema: a Morfema: a
# Lexema: message Lema: message Morfema: age
# Lexema: to Lema: to Morfema: to
# Lexema: the Lema: the Morfema: the
# Lexema: world Lema: world Morfema: rld
# Lexema: that Lema: that Morfema: hat
# Lexema: we Lema: we Morfema: we
# Lexema: have Lema: have Morfema: ave
# Lexema: never Lema: never Morfema: ver
# Lexema: been Lema: be Morfema: een
# Lexema: just Lema: just Morfema: ust
# Lexema: a Lema: a Morfema: a
# Lexema: collection Lema: collection Morfema: ion
# Lexema: of Lema: of Morfema: of
# Lexema: individuals Lema: individual Morfema: als
# Lexema: or Lema: or Morfema: or
# Lexema: a Lema: a Morfema: a
# Lexema: collection Lema: collection Morfema: ion
# Lexema: of Lema: of Morfema: of
# Lexema: red Lema: red Morfema: red
# Lexema: states Lema: state Morfema: tes
# Lexema: and Lema: and Morfema: and
# Lexema: blue Lema: blue Morfema: lue
# Lexema: states Lema: state Morfema: tes
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: We Lema: we Morfema: We
# Lexema: are Lema: be Morfema: are
# Lexema: , Lema: , Morfema: ,
# Lexema: and Lema: and Morfema: and
# Lexema: always Lema: always Morfema: ays
# Lexema: will Lema: will Morfema: ill
# Lexema: be Lema: be Morfema: be
# Lexema: , Lema: , Morfema: ,
# Lexema: the Lema: the Morfema: the
# Lexema: United Lema: United Morfema: ted
# Lexema: States Lema: States Morfema: tes
# Lexema: of Lema: of Morfema: of
# Lexema: America Lema: America Morfema: ica
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: It Lema: it Morfema: It
# Lexema: ’s Lema: ’ Morfema: ’s
# Lexema: the Lema: the Morfema: the
# Lexema: answer Lema: answer Morfema: wer
# Lexema: that Lema: that Morfema: hat
# Lexema: led Lema: lead Morfema: led
# Lexema: those Lema: those Morfema: ose
# Lexema: who Lema: who Morfema: who
# Lexema: ’ve Lema: ’ve Morfema: ’ve
# Lexema: been Lema: been Morfema: een
# Lexema: told Lema: tell Morfema: old
# Lexema: for Lema: for Morfema: for
# Lexema: so Lema: so Morfema: so
# Lexema: long Lema: long Morfema: ong
# Lexema: by Lema: by Morfema: by
# Lexema: so Lema: so Morfema: so
# Lexema: many Lema: many Morfema: any
# Lexema: to Lema: to Morfema: to
# Lexema: be Lema: be Morfema: be
# Lexema: cynical Lema: cynical Morfema: cal
# Lexema: and Lema: and Morfema: and
# Lexema: fearful Lema: fearful Morfema: ful
# Lexema: and Lema: and Morfema: and
# Lexema: doubtful Lema: doubtful Morfema: ful
# Lexema: about Lema: about Morfema: out
# Lexema: what Lema: what Morfema: hat
# Lexema: we Lema: we Morfema: we
# Lexema: can Lema: can Morfema: can
# Lexema: achieve Lema: achieve Morfema: eve
# Lexema: to Lema: to Morfema: to
# Lexema: put Lema: put Morfema: put
# Lexema: their Lema: their Morfema: eir
# Lexema: hands Lema: hand Morfema: nds
# Lexema: on Lema: on Morfema: on
# Lexema: the Lema: the Morfema: the
# Lexema: arc Lema: arc Morfema: arc
# Lexema: of Lema: of Morfema: of
# Lexema: history Lema: history Morfema: ory
# Lexema: and Lema: and Morfema: and
# Lexema: bend Lema: bend Morfema: end
# Lexema: it Lema: it Morfema: it
# Lexema: once Lema: once Morfema: nce
# Lexema: more Lema: more Morfema: ore
# Lexema: toward Lema: toward Morfema: ard
# Lexema: the Lema: the Morfema: the
# Lexema: hope Lema: hope Morfema: ope
# Lexema: of Lema: of Morfema: of
# Lexema: a Lema: a Morfema: a
# Lexema: better Lema: well Morfema: ter
# Lexema: day Lema: day Morfema: day
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: It Lema: it Morfema: It
# Lexema: ’s Lema: ’s Morfema: ’s
# Lexema: been Lema: be Morfema: een
# Lexema: a Lema: a Morfema: a
# Lexema: long Lema: long Morfema: ong
# Lexema: time Lema: time Morfema: ime
# Lexema: coming Lema: come Morfema: ing
# Lexema: , Lema: , Morfema: ,
# Lexema: but Lema: but Morfema: but
# Lexema: tonight Lema: tonight Morfema: ght
# Lexema: , Lema: , Morfema: ,
# Lexema: because Lema: because Morfema: use
# Lexema: of Lema: of Morfema: of
# Lexema: what Lema: what Morfema: hat
# Lexema: we Lema: we Morfema: we
# Lexema: did Lema: do Morfema: did
# Lexema: on Lema: on Morfema: on
# Lexema: this Lema: this Morfema: his
# Lexema: date Lema: date Morfema: ate
# Lexema: in Lema: in Morfema: in
# Lexema: this Lema: this Morfema: his
# Lexema: election Lema: election Morfema: ion
# Lexema: at Lema: at Morfema: at
# Lexema: this Lema: this Morfema: his
# Lexema: defining Lema: define Morfema: ing
# Lexema: moment Lema: moment Morfema: ent
# Lexema: change Lema: change Morfema: nge
# Lexema: has Lema: have Morfema: has
# Lexema: come Lema: come Morfema: ome
# Lexema: to Lema: to Morfema: to
# Lexema: America Lema: America Morfema: ica
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: [ Lema: [ Morfema: [
# Lexema: read Lema: read Morfema: ead
# Lexema: more Lema: more Morfema: ore
# Lexema: ] Lema: ] Morfema: ]
# Lexema:
#
#  Lema:
#
#  Morfema:
#
#
# Lexema: We Lema: we Morfema: We
# Lexema: did Lema: do Morfema: did
# Lexema: n’t Lema: not Morfema: n’t
# Lexema: start Lema: start Morfema: art
# Lexema: with Lema: with Morfema: ith
# Lexema: much Lema: much Morfema: uch
# Lexema: money Lema: money Morfema: ney
# Lexema: or Lema: or Morfema: or
# Lexema: many Lema: many Morfema: any
# Lexema: endorsements Lema: endorsement Morfema: nts
# Lexema: . Lema: . Morfema: .
# Lexema: Our Lema: our Morfema: Our
# Lexema: campaign Lema: campaign Morfema: ign
# Lexema: was Lema: be Morfema: was
# Lexema: not Lema: not Morfema: not
# Lexema: hatched Lema: hatch Morfema: hed
# Lexema: in Lema: in Morfema: in
# Lexema: the Lema: the Morfema: the
# Lexema: halls Lema: hall Morfema: lls
# Lexema: of Lema: of Morfema: of
# Lexema: Washington Lema: Washington Morfema: ton
# Lexema: . Lema: . Morfema: .
# Lexema: It Lema: it Morfema: It
# Lexema: began Lema: begin Morfema: gan
# Lexema: in Lema: in Morfema: in
# Lexema: the Lema: the Morfema: the
# Lexema: backyards Lema: backyard Morfema: rds
# Lexema: of Lema: of Morfema: of
# Lexema: Des Lema: Des Morfema: Des
# Lexema: Moines Lema: Moines Morfema: nes
# Lexema: and Lema: and Morfema: and
# Lexema: the Lema: the Morfema: the
# Lexema: living Lema: live Morfema: ing
# Lexema: rooms Lema: room Morfema: oms
# Lexema: of Lema: of Morfema: of
# Lexema: Concord Lema: Concord Morfema: ord
# Lexema: and Lema: and Morfema: and
# Lexema: the Lema: the Morfema: the
# Lexema: front Lema: front Morfema: ont
# Lexema: porches Lema: porch Morfema: hes
# Lexema: of Lema: of Morfema: of
# Lexema: Charleston Lema: Charleston Morfema: ton
# Lexema: . Lema: . Morfema: .
# Lexema: It Lema: it Morfema: It
# Lexema: was Lema: be Morfema: was
# Lexema: built Lema: build Morfema: ilt
# Lexema: by Lema: by Morfema: by
# Lexema: working Lema: work Morfema: ing
# Lexema: men Lema: man Morfema: men
# Lexema: and Lema: and Morfema: and
# Lexema: women Lema: woman Morfema: men
# Lexema: who Lema: who Morfema: who
# Lexema: dug Lema: dig Morfema: dug
# Lexema: into Lema: into Morfema: nto
# Lexema: what Lema: what Morfema: hat
# Lexema: little Lema: little Morfema: tle
# Lexema: savings Lema: saving Morfema: ngs
# Lexema: they Lema: they Morfema: hey
# Lexema: had Lema: have Morfema: had
# Lexema: to Lema: to Morfema: to
# Lexema: give Lema: give Morfema: ive
# Lexema: $ Lema: $ Morfema: $
# Lexema: 5 Lema: 5 Morfema: 5
# Lexema: and Lema: and Morfema: and
# Lexema: $ Lema: $ Morfema: $
# Lexema: 10 Lema: 10 Morfema: 10
# Lexema: and Lema: and Morfema: and
# Lexema: $ Lema: $ Morfema: $
# Lexema: 20 Lema: 20 Morfema: 20
# Lexema: to Lema: to Morfema: to
# Lexema: the Lema: the Morfema: the
# Lexema: cause Lema: cause Morfema: use
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: It Lema: it Morfema: It
# Lexema: grew Lema: grow Morfema: rew
# Lexema: strength Lema: strength Morfema: gth
# Lexema: from Lema: from Morfema: rom
# Lexema: the Lema: the Morfema: the
# Lexema: young Lema: young Morfema: ung
# Lexema: people Lema: people Morfema: ple
# Lexema: who Lema: who Morfema: who
# Lexema: rejected Lema: reject Morfema: ted
# Lexema: the Lema: the Morfema: the
# Lexema: myth Lema: myth Morfema: yth
# Lexema: of Lema: of Morfema: of
# Lexema: their Lema: their Morfema: eir
# Lexema: generation Lema: generation Morfema: ion
# Lexema: ’s Lema: ’s Morfema: ’s
# Lexema: apathy Lema: apathy Morfema: thy
# Lexema: who Lema: who Morfema: who
# Lexema: left Lema: leave Morfema: eft
# Lexema: their Lema: their Morfema: eir
# Lexema: homes Lema: home Morfema: mes
# Lexema: and Lema: and Morfema: and
# Lexema: their Lema: their Morfema: eir
# Lexema: families Lema: family Morfema: ies
# Lexema: for Lema: for Morfema: for
# Lexema: jobs Lema: job Morfema: obs
# Lexema: that Lema: that Morfema: hat
# Lexema: offered Lema: offer Morfema: red
# Lexema: little Lema: little Morfema: tle
# Lexema: pay Lema: pay Morfema: pay
# Lexema: and Lema: and Morfema: and
# Lexema: less Lema: less Morfema: ess
# Lexema: sleep Lema: sleep Morfema: eep
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: It Lema: it Morfema: It
# Lexema: drew Lema: draw Morfema: rew
# Lexema: strength Lema: strength Morfema: gth
# Lexema: from Lema: from Morfema: rom
# Lexema: the Lema: the Morfema: the
# Lexema: not Lema: not Morfema: not
# Lexema: - Lema: - Morfema: -
# Lexema: so Lema: so Morfema: so
# Lexema: - Lema: - Morfema: -
# Lexema: young Lema: young Morfema: ung
# Lexema: people Lema: people Morfema: ple
# Lexema: who Lema: who Morfema: who
# Lexema: braved Lema: brave Morfema: ved
# Lexema: the Lema: the Morfema: the
# Lexema: bitter Lema: bitter Morfema: ter
# Lexema: cold Lema: cold Morfema: old
# Lexema: and Lema: and Morfema: and
# Lexema: scorching Lema: scorch Morfema: ing
# Lexema: heat Lema: heat Morfema: eat
# Lexema: to Lema: to Morfema: to
# Lexema: knock Lema: knock Morfema: ock
# Lexema: on Lema: on Morfema: on
# Lexema: doors Lema: door Morfema: ors
# Lexema: of Lema: of Morfema: of
# Lexema: perfect Lema: perfect Morfema: ect
# Lexema: strangers Lema: stranger Morfema: ers
# Lexema: , Lema: , Morfema: ,
# Lexema: and Lema: and Morfema: and
# Lexema: from Lema: from Morfema: rom
# Lexema: the Lema: the Morfema: the
# Lexema: millions Lema: million Morfema: ons
# Lexema: of Lema: of Morfema: of
# Lexema: Americans Lema: Americans Morfema: ans
# Lexema: who Lema: who Morfema: who
# Lexema: volunteered Lema: volunteer Morfema: red
# Lexema: and Lema: and Morfema: and
# Lexema: organized Lema: organize Morfema: zed
# Lexema: and Lema: and Morfema: and
# Lexema: proved Lema: prove Morfema: ved
# Lexema: that Lema: that Morfema: hat
# Lexema: more Lema: more Morfema: ore
# Lexema: than Lema: than Morfema: han
# Lexema: two Lema: two Morfema: two
# Lexema: centuries Lema: century Morfema: ies
# Lexema: later Lema: later Morfema: ter
# Lexema: a Lema: a Morfema: a
# Lexema: government Lema: government Morfema: ent
# Lexema: of Lema: of Morfema: of
# Lexema: the Lema: the Morfema: the
# Lexema: people Lema: people Morfema: ple
# Lexema: , Lema: , Morfema: ,
# Lexema: by Lema: by Morfema: by
# Lexema: the Lema: the Morfema: the
# Lexema: people Lema: people Morfema: ple
# Lexema: , Lema: , Morfema: ,
# Lexema: and Lema: and Morfema: and
# Lexema: for Lema: for Morfema: for
# Lexema: the Lema: the Morfema: the
# Lexema: people Lema: people Morfema: ple
# Lexema: has Lema: have Morfema: has
# Lexema: not Lema: not Morfema: not
# Lexema: perished Lema: perish Morfema: hed
# Lexema: from Lema: from Morfema: rom
# Lexema: the Lema: the Morfema: the
# Lexema: Earth Lema: Earth Morfema: rth
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: This Lema: this Morfema: his
# Lexema: is Lema: be Morfema: is
# Lexema: your Lema: your Morfema: our
# Lexema: victory Lema: victory Morfema: ory
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: And Lema: and Morfema: And
# Lexema: I Lema: I Morfema: I
# Lexema: know Lema: know Morfema: now
# Lexema: you Lema: you Morfema: you
# Lexema: did Lema: do Morfema: did
# Lexema: n’t Lema: not Morfema: n’t
# Lexema: do Lema: do Morfema: do
# Lexema: this Lema: this Morfema: his
# Lexema: just Lema: just Morfema: ust
# Lexema: to Lema: to Morfema: to
# Lexema: win Lema: win Morfema: win
# Lexema: an Lema: an Morfema: an
# Lexema: election Lema: election Morfema: ion
# Lexema: . Lema: . Morfema: .
# Lexema: And Lema: and Morfema: And
# Lexema: I Lema: I Morfema: I
# Lexema: know Lema: know Morfema: now
# Lexema: you Lema: you Morfema: you
# Lexema: did Lema: do Morfema: did
# Lexema: n’t Lema: not Morfema: n’t
# Lexema: do Lema: do Morfema: do
# Lexema: it Lema: it Morfema: it
# Lexema: for Lema: for Morfema: for
# Lexema: me Lema: I Morfema: me
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: You Lema: you Morfema: You
# Lexema: did Lema: do Morfema: did
# Lexema: it Lema: it Morfema: it
# Lexema: because Lema: because Morfema: use
# Lexema: you Lema: you Morfema: you
# Lexema: understand Lema: understand Morfema: and
# Lexema: the Lema: the Morfema: the
# Lexema: enormity Lema: enormity Morfema: ity
# Lexema: of Lema: of Morfema: of
# Lexema: the Lema: the Morfema: the
# Lexema: task Lema: task Morfema: ask
# Lexema: that Lema: that Morfema: hat
# Lexema: lies Lema: lie Morfema: ies
# Lexema: ahead Lema: ahead Morfema: ead
# Lexema: . Lema: . Morfema: .
# Lexema: For Lema: for Morfema: For
# Lexema: even Lema: even Morfema: ven
# Lexema: as Lema: as Morfema: as
# Lexema: we Lema: we Morfema: we
# Lexema: celebrate Lema: celebrate Morfema: ate
# Lexema: tonight Lema: tonight Morfema: ght
# Lexema: , Lema: , Morfema: ,
# Lexema: we Lema: we Morfema: we
# Lexema: know Lema: know Morfema: now
# Lexema: the Lema: the Morfema: the
# Lexema: challenges Lema: challenge Morfema: ges
# Lexema: that Lema: that Morfema: hat
# Lexema: tomorrow Lema: tomorrow Morfema: row
# Lexema: will Lema: will Morfema: ill
# Lexema: bring Lema: bring Morfema: ing
# Lexema: are Lema: be Morfema: are
# Lexema: the Lema: the Morfema: the
# Lexema: greatest Lema: great Morfema: est
# Lexema: of Lema: of Morfema: of
# Lexema: our Lema: our Morfema: our
# Lexema: lifetime Lema: lifetime Morfema: ime
# Lexema: — Lema: — Morfema: —
# Lexema: two Lema: two Morfema: two
# Lexema: wars Lema: war Morfema: ars
# Lexema: , Lema: , Morfema: ,
# Lexema: a Lema: a Morfema: a
# Lexema: planet Lema: planet Morfema: net
# Lexema: in Lema: in Morfema: in
# Lexema: peril Lema: peril Morfema: ril
# Lexema: , Lema: , Morfema: ,
# Lexema: the Lema: the Morfema: the
# Lexema: worst Lema: bad Morfema: rst
# Lexema: financial Lema: financial Morfema: ial
# Lexema: crisis Lema: crisis Morfema: sis
# Lexema: in Lema: in Morfema: in
# Lexema: a Lema: a Morfema: a
# Lexema: century Lema: century Morfema: ury
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: Even Lema: even Morfema: ven
# Lexema: as Lema: as Morfema: as
# Lexema: we Lema: we Morfema: we
# Lexema: stand Lema: stand Morfema: and
# Lexema: here Lema: here Morfema: ere
# Lexema: tonight Lema: tonight Morfema: ght
# Lexema: , Lema: , Morfema: ,
# Lexema: we Lema: we Morfema: we
# Lexema: know Lema: know Morfema: now
# Lexema: there Lema: there Morfema: ere
# Lexema: are Lema: be Morfema: are
# Lexema: brave Lema: brave Morfema: ave
# Lexema: Americans Lema: Americans Morfema: ans
# Lexema: waking Lema: wake Morfema: ing
# Lexema: up Lema: up Morfema: up
# Lexema: in Lema: in Morfema: in
# Lexema: the Lema: the Morfema: the
# Lexema: deserts Lema: desert Morfema: rts
# Lexema: of Lema: of Morfema: of
# Lexema: Iraq Lema: Iraq Morfema: raq
# Lexema: and Lema: and Morfema: and
# Lexema: the Lema: the Morfema: the
# Lexema: mountains Lema: mountain Morfema: ins
# Lexema: of Lema: of Morfema: of
# Lexema: Afghanistan Lema: Afghanistan Morfema: tan
# Lexema: to Lema: to Morfema: to
# Lexema: risk Lema: risk Morfema: isk
# Lexema: their Lema: their Morfema: eir
# Lexema: lives Lema: life Morfema: ves
# Lexema: for Lema: for Morfema: for
# Lexema: us Lema: we Morfema: us
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: There Lema: there Morfema: ere
# Lexema: are Lema: be Morfema: are
# Lexema: mothers Lema: mother Morfema: ers
# Lexema: and Lema: and Morfema: and
# Lexema: fathers Lema: father Morfema: ers
# Lexema: who Lema: who Morfema: who
# Lexema: will Lema: will Morfema: ill
# Lexema: lie Lema: lie Morfema: lie
# Lexema: awake Lema: awake Morfema: ake
# Lexema: after Lema: after Morfema: ter
# Lexema: the Lema: the Morfema: the
# Lexema: children Lema: child Morfema: ren
# Lexema: fall Lema: fall Morfema: all
# Lexema: asleep Lema: asleep Morfema: eep
# Lexema: and Lema: and Morfema: and
# Lexema: wonder Lema: wonder Morfema: der
# Lexema: how Lema: how Morfema: how
# Lexema: they Lema: they Morfema: hey
# Lexema: ’ll Lema: ’ll Morfema: ’ll
# Lexema: make Lema: make Morfema: ake
# Lexema: the Lema: the Morfema: the
# Lexema: mortgage Lema: mortgage Morfema: age
# Lexema: or Lema: or Morfema: or
# Lexema: pay Lema: pay Morfema: pay
# Lexema: their Lema: their Morfema: eir
# Lexema: doctors Lema: doctor Morfema: ors
# Lexema: ’ Lema: ’ Morfema: ’
# Lexema: bills Lema: bill Morfema: lls
# Lexema: or Lema: or Morfema: or
# Lexema: save Lema: save Morfema: ave
# Lexema: enough Lema: enough Morfema: ugh
# Lexema: for Lema: for Morfema: for
# Lexema: their Lema: their Morfema: eir
# Lexema: child Lema: child Morfema: ild
# Lexema: ’s Lema: ’s Morfema: ’s
# Lexema: college Lema: college Morfema: ege
# Lexema: education Lema: education Morfema: ion
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: There Lema: there Morfema: ere
# Lexema: ’s Lema: ’ Morfema: ’s
# Lexema: new Lema: new Morfema: new
# Lexema: energy Lema: energy Morfema: rgy
# Lexema: to Lema: to Morfema: to
# Lexema: harness Lema: harness Morfema: ess
# Lexema: , Lema: , Morfema: ,
# Lexema: new Lema: new Morfema: new
# Lexema: jobs Lema: job Morfema: obs
# Lexema: to Lema: to Morfema: to
# Lexema: be Lema: be Morfema: be
# Lexema: created Lema: create Morfema: ted
# Lexema: , Lema: , Morfema: ,
# Lexema: new Lema: new Morfema: new
# Lexema: schools Lema: school Morfema: ols
# Lexema: to Lema: to Morfema: to
# Lexema: build Lema: build Morfema: ild
# Lexema: , Lema: , Morfema: ,
# Lexema: and Lema: and Morfema: and
# Lexema: threats Lema: threat Morfema: ats
# Lexema: to Lema: to Morfema: to
# Lexema: meet Lema: meet Morfema: eet
# Lexema: , Lema: , Morfema: ,
# Lexema: alliances Lema: alliance Morfema: ces
# Lexema: to Lema: to Morfema: to
# Lexema: repair Lema: repair Morfema: air
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: The Lema: the Morfema: The
# Lexema: road Lema: road Morfema: oad
# Lexema: ahead Lema: ahead Morfema: ead
# Lexema: will Lema: will Morfema: ill
# Lexema: be Lema: be Morfema: be
# Lexema: long Lema: long Morfema: ong
# Lexema: . Lema: . Morfema: .
# Lexema: Our Lema: our Morfema: Our
# Lexema: climb Lema: climb Morfema: imb
# Lexema: will Lema: will Morfema: ill
# Lexema: be Lema: be Morfema: be
# Lexema: steep Lema: steep Morfema: eep
# Lexema: . Lema: . Morfema: .
# Lexema: We Lema: we Morfema: We
# Lexema: may Lema: may Morfema: may
# Lexema: not Lema: not Morfema: not
# Lexema: get Lema: get Morfema: get
# Lexema: there Lema: there Morfema: ere
# Lexema: in Lema: in Morfema: in
# Lexema: one Lema: one Morfema: one
# Lexema: year Lema: year Morfema: ear
# Lexema: or Lema: or Morfema: or
# Lexema: even Lema: even Morfema: ven
# Lexema: in Lema: in Morfema: in
# Lexema: one Lema: one Morfema: one
# Lexema: term Lema: term Morfema: erm
# Lexema: . Lema: . Morfema: .
# Lexema: But Lema: but Morfema: But
# Lexema: , Lema: , Morfema: ,
# Lexema: America Lema: America Morfema: ica
# Lexema: , Lema: , Morfema: ,
# Lexema: I Lema: I Morfema: I
# Lexema: have Lema: have Morfema: ave
# Lexema: never Lema: never Morfema: ver
# Lexema: been Lema: be Morfema: een
# Lexema: more Lema: more Morfema: ore
# Lexema: hopeful Lema: hopeful Morfema: ful
# Lexema: than Lema: than Morfema: han
# Lexema: I Lema: I Morfema: I
# Lexema: am Lema: be Morfema: am
# Lexema: tonight Lema: tonight Morfema: ght
# Lexema: that Lema: that Morfema: hat
# Lexema: we Lema: we Morfema: we
# Lexema: will Lema: will Morfema: ill
# Lexema: get Lema: get Morfema: get
# Lexema: there Lema: there Morfema: ere
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: I Lema: I Morfema: I
# Lexema: promise Lema: promise Morfema: ise
# Lexema: you Lema: you Morfema: you
# Lexema: , Lema: , Morfema: ,
# Lexema: we Lema: we Morfema: we
# Lexema: as Lema: as Morfema: as
# Lexema: a Lema: a Morfema: a
# Lexema: people Lema: people Morfema: ple
# Lexema: will Lema: will Morfema: ill
# Lexema: get Lema: get Morfema: get
# Lexema: there Lema: there Morfema: ere
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: There Lema: there Morfema: ere
# Lexema: will Lema: will Morfema: ill
# Lexema: be Lema: be Morfema: be
# Lexema: setbacks Lema: setback Morfema: cks
# Lexema: and Lema: and Morfema: and
# Lexema: false Lema: false Morfema: lse
# Lexema: starts Lema: start Morfema: rts
# Lexema: . Lema: . Morfema: .
# Lexema: There Lema: there Morfema: ere
# Lexema: are Lema: be Morfema: are
# Lexema: many Lema: many Morfema: any
# Lexema: who Lema: who Morfema: who
# Lexema: wo Lema: will Morfema: wo
# Lexema: n’t Lema: not Morfema: n’t
# Lexema: agree Lema: agree Morfema: ree
# Lexema: with Lema: with Morfema: ith
# Lexema: every Lema: every Morfema: ery
# Lexema: decision Lema: decision Morfema: ion
# Lexema: or Lema: or Morfema: or
# Lexema: policy Lema: policy Morfema: icy
# Lexema: I Lema: I Morfema: I
# Lexema: make Lema: make Morfema: ake
# Lexema: as Lema: as Morfema: as
# Lexema: president Lema: president Morfema: ent
# Lexema: . Lema: . Morfema: .
# Lexema: And Lema: and Morfema: And
# Lexema: we Lema: we Morfema: we
# Lexema: know Lema: know Morfema: now
# Lexema: the Lema: the Morfema: the
# Lexema: government Lema: government Morfema: ent
# Lexema: ca Lema: can Morfema: ca
# Lexema: n’t Lema: not Morfema: n’t
# Lexema: solve Lema: solve Morfema: lve
# Lexema: every Lema: every Morfema: ery
# Lexema: problem Lema: problem Morfema: lem
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: But Lema: but Morfema: But
# Lexema: I Lema: I Morfema: I
# Lexema: will Lema: will Morfema: ill
# Lexema: always Lema: always Morfema: ays
# Lexema: be Lema: be Morfema: be
# Lexema: honest Lema: honest Morfema: est
# Lexema: with Lema: with Morfema: ith
# Lexema: you Lema: you Morfema: you
# Lexema: about Lema: about Morfema: out
# Lexema: the Lema: the Morfema: the
# Lexema: challenges Lema: challenge Morfema: ges
# Lexema: we Lema: we Morfema: we
# Lexema: face Lema: face Morfema: ace
# Lexema: . Lema: . Morfema: .
# Lexema: I Lema: I Morfema: I
# Lexema: will Lema: will Morfema: ill
# Lexema: listen Lema: listen Morfema: ten
# Lexema: to Lema: to Morfema: to
# Lexema: you Lema: you Morfema: you
# Lexema: , Lema: , Morfema: ,
# Lexema: especially Lema: especially Morfema: lly
# Lexema: when Lema: when Morfema: hen
# Lexema: we Lema: we Morfema: we
# Lexema: disagree Lema: disagree Morfema: ree
# Lexema: . Lema: . Morfema: .
# Lexema: And Lema: and Morfema: And
# Lexema: , Lema: , Morfema: ,
# Lexema: above Lema: above Morfema: ove
# Lexema: all Lema: all Morfema: all
# Lexema: , Lema: , Morfema: ,
# Lexema: I Lema: I Morfema: I
# Lexema: will Lema: will Morfema: ill
# Lexema: ask Lema: ask Morfema: ask
# Lexema: you Lema: you Morfema: you
# Lexema: to Lema: to Morfema: to
# Lexema: join Lema: join Morfema: oin
# Lexema: in Lema: in Morfema: in
# Lexema: the Lema: the Morfema: the
# Lexema: work Lema: work Morfema: ork
# Lexema: of Lema: of Morfema: of
# Lexema: remaking Lema: remake Morfema: ing
# Lexema: this Lema: this Morfema: his
# Lexema: nation Lema: nation Morfema: ion
# Lexema: , Lema: , Morfema: ,
# Lexema: the Lema: the Morfema: the
# Lexema: only Lema: only Morfema: nly
# Lexema: way Lema: way Morfema: way
# Lexema: it Lema: it Morfema: it
# Lexema: ’s Lema: ’s Morfema: ’s
# Lexema: been Lema: be Morfema: een
# Lexema: done Lema: do Morfema: one
# Lexema: in Lema: in Morfema: in
# Lexema: America Lema: America Morfema: ica
# Lexema: for Lema: for Morfema: for
# Lexema: 221 Lema: 221 Morfema: 221
# Lexema: years Lema: year Morfema: ars
# Lexema: — Lema: — Morfema: —
# Lexema: block Lema: block Morfema: ock
# Lexema: by Lema: by Morfema: by
# Lexema: block Lema: block Morfema: ock
# Lexema: , Lema: , Morfema: ,
# Lexema: brick Lema: brick Morfema: ick
# Lexema: by Lema: by Morfema: by
# Lexema: brick Lema: brick Morfema: ick
# Lexema: , Lema: , Morfema: ,
# Lexema: calloused Lema: calloused Morfema: sed
# Lexema: hand Lema: hand Morfema: and
# Lexema: by Lema: by Morfema: by
# Lexema: calloused Lema: calloused Morfema: sed
# Lexema: hand Lema: hand Morfema: and
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: What Lema: what Morfema: hat
# Lexema: began Lema: begin Morfema: gan
# Lexema: 21 Lema: 21 Morfema: 21
# Lexema: months Lema: month Morfema: ths
# Lexema: ago Lema: ago Morfema: ago
# Lexema: in Lema: in Morfema: in
# Lexema: the Lema: the Morfema: the
# Lexema: depths Lema: depth Morfema: ths
# Lexema: of Lema: of Morfema: of
# Lexema: winter Lema: winter Morfema: ter
# Lexema: can Lema: can Morfema: can
# Lexema: not Lema: not Morfema: not
# Lexema: end Lema: end Morfema: end
# Lexema: on Lema: on Morfema: on
# Lexema: this Lema: this Morfema: his
# Lexema: autumn Lema: autumn Morfema: umn
# Lexema: night Lema: night Morfema: ght
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: This Lema: this Morfema: his
# Lexema: victory Lema: victory Morfema: ory
# Lexema: alone Lema: alone Morfema: one
# Lexema: is Lema: be Morfema: is
# Lexema: not Lema: not Morfema: not
# Lexema: the Lema: the Morfema: the
# Lexema: change Lema: change Morfema: nge
# Lexema: we Lema: we Morfema: we
# Lexema: seek Lema: seek Morfema: eek
# Lexema: . Lema: . Morfema: .
# Lexema: It Lema: it Morfema: It
# Lexema: is Lema: be Morfema: is
# Lexema: only Lema: only Morfema: nly
# Lexema: the Lema: the Morfema: the
# Lexema: chance Lema: chance Morfema: nce
# Lexema: for Lema: for Morfema: for
# Lexema: us Lema: we Morfema: us
# Lexema: to Lema: to Morfema: to
# Lexema: make Lema: make Morfema: ake
# Lexema: that Lema: that Morfema: hat
# Lexema: change Lema: change Morfema: nge
# Lexema: . Lema: . Morfema: .
# Lexema: And Lema: and Morfema: And
# Lexema: that Lema: that Morfema: hat
# Lexema: can Lema: can Morfema: can
# Lexema: not Lema: not Morfema: not
# Lexema: happen Lema: happen Morfema: pen
# Lexema: if Lema: if Morfema: if
# Lexema: we Lema: we Morfema: we
# Lexema: go Lema: go Morfema: go
# Lexema: back Lema: back Morfema: ack
# Lexema: to Lema: to Morfema: to
# Lexema: the Lema: the Morfema: the
# Lexema: way Lema: way Morfema: way
# Lexema: things Lema: thing Morfema: ngs
# Lexema: were Lema: be Morfema: ere
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: It Lema: it Morfema: It
# Lexema: ca Lema: can Morfema: ca
# Lexema: n’t Lema: not Morfema: n’t
# Lexema: happen Lema: happen Morfema: pen
# Lexema: without Lema: without Morfema: out
# Lexema: you Lema: you Morfema: you
# Lexema: , Lema: , Morfema: ,
# Lexema: without Lema: without Morfema: out
# Lexema: a Lema: a Morfema: a
# Lexema: new Lema: new Morfema: new
# Lexema: spirit Lema: spirit Morfema: rit
# Lexema: of Lema: of Morfema: of
# Lexema: service Lema: service Morfema: ice
# Lexema: , Lema: , Morfema: ,
# Lexema: a Lema: a Morfema: a
# Lexema: new Lema: new Morfema: new
# Lexema: spirit Lema: spirit Morfema: rit
# Lexema: of Lema: of Morfema: of
# Lexema: sacrifice Lema: sacrifice Morfema: ice
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: So Lema: so Morfema: So
# Lexema: let Lema: let Morfema: let
# Lexema: us Lema: we Morfema: us
# Lexema: summon Lema: summon Morfema: mon
# Lexema: a Lema: a Morfema: a
# Lexema: new Lema: new Morfema: new
# Lexema: spirit Lema: spirit Morfema: rit
# Lexema: of Lema: of Morfema: of
# Lexema: patriotism Lema: patriotism Morfema: ism
# Lexema: , Lema: , Morfema: ,
# Lexema: of Lema: of Morfema: of
# Lexema: responsibility Lema: responsibility Morfema: ity
# Lexema: , Lema: , Morfema: ,
# Lexema: where Lema: where Morfema: ere
# Lexema: each Lema: each Morfema: ach
# Lexema: of Lema: of Morfema: of
# Lexema: us Lema: we Morfema: us
# Lexema: resolves Lema: resolve Morfema: ves
# Lexema: to Lema: to Morfema: to
# Lexema: pitch Lema: pitch Morfema: tch
# Lexema: in Lema: in Morfema: in
# Lexema: and Lema: and Morfema: and
# Lexema: work Lema: work Morfema: ork
# Lexema: harder Lema: hard Morfema: der
# Lexema: and Lema: and Morfema: and
# Lexema: look Lema: look Morfema: ook
# Lexema: after Lema: after Morfema: ter
# Lexema: not Lema: not Morfema: not
# Lexema: only Lema: only Morfema: nly
# Lexema: ourselves Lema: ourselves Morfema: ves
# Lexema: but Lema: but Morfema: but
# Lexema: each Lema: each Morfema: ach
# Lexema: other Lema: other Morfema: her
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: Let Lema: let Morfema: Let
# Lexema: us Lema: we Morfema: us
# Lexema: remember Lema: remember Morfema: ber
# Lexema: that Lema: that Morfema: hat
# Lexema: , Lema: , Morfema: ,
# Lexema: if Lema: if Morfema: if
# Lexema: this Lema: this Morfema: his
# Lexema: financial Lema: financial Morfema: ial
# Lexema: crisis Lema: crisis Morfema: sis
# Lexema: taught Lema: teach Morfema: ght
# Lexema: us Lema: we Morfema: us
# Lexema: anything Lema: anything Morfema: ing
# Lexema: , Lema: , Morfema: ,
# Lexema: it Lema: it Morfema: it
# Lexema: ’s Lema: ’ Morfema: ’s
# Lexema: that Lema: that Morfema: hat
# Lexema: we Lema: we Morfema: we
# Lexema: can Lema: can Morfema: can
# Lexema: not Lema: not Morfema: not
# Lexema: have Lema: have Morfema: ave
# Lexema: a Lema: a Morfema: a
# Lexema: thriving Lema: thriving Morfema: ing
# Lexema: Wall Lema: Wall Morfema: all
# Lexema: Street Lema: Street Morfema: eet
# Lexema: while Lema: while Morfema: ile
# Lexema: Main Lema: Main Morfema: ain
# Lexema: Street Lema: Street Morfema: eet
# Lexema: suffers Lema: suffer Morfema: ers
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: In Lema: in Morfema: In
# Lexema: this Lema: this Morfema: his
# Lexema: country Lema: country Morfema: try
# Lexema: , Lema: , Morfema: ,
# Lexema: we Lema: we Morfema: we
# Lexema: rise Lema: rise Morfema: ise
# Lexema: or Lema: or Morfema: or
# Lexema: fall Lema: fall Morfema: all
# Lexema: as Lema: as Morfema: as
# Lexema: one Lema: one Morfema: one
# Lexema: nation Lema: nation Morfema: ion
# Lexema: , Lema: , Morfema: ,
# Lexema: as Lema: as Morfema: as
# Lexema: one Lema: one Morfema: one
# Lexema: people Lema: people Morfema: ple
# Lexema: . Lema: . Morfema: .
# Lexema: Let Lema: let Morfema: Let
# Lexema: ’s Lema: ’s Morfema: ’s
# Lexema: resist Lema: resist Morfema: ist
# Lexema: the Lema: the Morfema: the
# Lexema: temptation Lema: temptation Morfema: ion
# Lexema: to Lema: to Morfema: to
# Lexema: fall Lema: fall Morfema: all
# Lexema: back Lema: back Morfema: ack
# Lexema: on Lema: on Morfema: on
# Lexema: the Lema: the Morfema: the
# Lexema: same Lema: same Morfema: ame
# Lexema: partisanship Lema: partisanship Morfema: hip
# Lexema: and Lema: and Morfema: and
# Lexema: pettiness Lema: pettiness Morfema: ess
# Lexema: and Lema: and Morfema: and
# Lexema: immaturity Lema: immaturity Morfema: ity
# Lexema: that Lema: that Morfema: hat
# Lexema: has Lema: have Morfema: has
# Lexema: poisoned Lema: poison Morfema: ned
# Lexema: our Lema: our Morfema: our
# Lexema: politics Lema: politic Morfema: ics
# Lexema: for Lema: for Morfema: for
# Lexema: so Lema: so Morfema: so
# Lexema: long Lema: long Morfema: ong
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: Let Lema: let Morfema: Let
# Lexema: ’s Lema: ’s Morfema: ’s
# Lexema: remember Lema: remember Morfema: ber
# Lexema: that Lema: that Morfema: hat
# Lexema: it Lema: it Morfema: it
# Lexema: was Lema: be Morfema: was
# Lexema: a Lema: a Morfema: a
# Lexema: man Lema: man Morfema: man
# Lexema: from Lema: from Morfema: rom
# Lexema: this Lema: this Morfema: his
# Lexema: state Lema: state Morfema: ate
# Lexema: who Lema: who Morfema: who
# Lexema: first Lema: first Morfema: rst
# Lexema: carried Lema: carry Morfema: ied
# Lexema: the Lema: the Morfema: the
# Lexema: banner Lema: banner Morfema: ner
# Lexema: of Lema: of Morfema: of
# Lexema: the Lema: the Morfema: the
# Lexema: Republican Lema: Republican Morfema: can
# Lexema: Party Lema: Party Morfema: rty
# Lexema: to Lema: to Morfema: to
# Lexema: the Lema: the Morfema: the
# Lexema: White Lema: White Morfema: ite
# Lexema: House Lema: House Morfema: use
# Lexema: , Lema: , Morfema: ,
# Lexema: a Lema: a Morfema: a
# Lexema: party Lema: party Morfema: rty
# Lexema: founded Lema: found Morfema: ded
# Lexema: on Lema: on Morfema: on
# Lexema: the Lema: the Morfema: the
# Lexema: values Lema: value Morfema: ues
# Lexema: of Lema: of Morfema: of
# Lexema: self Lema: self Morfema: elf
# Lexema: - Lema: - Morfema: -
# Lexema: reliance Lema: reliance Morfema: nce
# Lexema: and Lema: and Morfema: and
# Lexema: individual Lema: individual Morfema: ual
# Lexema: liberty Lema: liberty Morfema: rty
# Lexema: and Lema: and Morfema: and
# Lexema: national Lema: national Morfema: nal
# Lexema: unity Lema: unity Morfema: ity
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: Those Lema: those Morfema: ose
# Lexema: are Lema: be Morfema: are
# Lexema: values Lema: value Morfema: ues
# Lexema: that Lema: that Morfema: hat
# Lexema: we Lema: we Morfema: we
# Lexema: all Lema: all Morfema: all
# Lexema: share Lema: share Morfema: are
# Lexema: . Lema: . Morfema: .
# Lexema: And Lema: and Morfema: And
# Lexema: while Lema: while Morfema: ile
# Lexema: the Lema: the Morfema: the
# Lexema: Democratic Lema: Democratic Morfema: tic
# Lexema: Party Lema: Party Morfema: rty
# Lexema: has Lema: have Morfema: has
# Lexema: won Lema: win Morfema: won
# Lexema: a Lema: a Morfema: a
# Lexema: great Lema: great Morfema: eat
# Lexema: victory Lema: victory Morfema: ory
# Lexema: tonight Lema: tonight Morfema: ght
# Lexema: , Lema: , Morfema: ,
# Lexema: we Lema: we Morfema: we
# Lexema: do Lema: do Morfema: do
# Lexema: so Lema: so Morfema: so
# Lexema: with Lema: with Morfema: ith
# Lexema: a Lema: a Morfema: a
# Lexema: measure Lema: measure Morfema: ure
# Lexema: of Lema: of Morfema: of
# Lexema: humility Lema: humility Morfema: ity
# Lexema: and Lema: and Morfema: and
# Lexema: determination Lema: determination Morfema: ion
# Lexema: to Lema: to Morfema: to
# Lexema: heal Lema: heal Morfema: eal
# Lexema: the Lema: the Morfema: the
# Lexema: divides Lema: divide Morfema: des
# Lexema: that Lema: that Morfema: hat
# Lexema: have Lema: have Morfema: ave
# Lexema: held Lema: hold Morfema: eld
# Lexema: back Lema: back Morfema: ack
# Lexema: our Lema: our Morfema: our
# Lexema: progress Lema: progress Morfema: ess
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: As Lema: as Morfema: As
# Lexema: Lincoln Lema: Lincoln Morfema: oln
# Lexema: said Lema: say Morfema: aid
# Lexema: to Lema: to Morfema: to
# Lexema: a Lema: a Morfema: a
# Lexema: nation Lema: nation Morfema: ion
# Lexema: far Lema: far Morfema: far
# Lexema: more Lema: more Morfema: ore
# Lexema: divided Lema: divided Morfema: ded
# Lexema: than Lema: than Morfema: han
# Lexema: ours Lema: our Morfema: urs
# Lexema: , Lema: , Morfema: ,
# Lexema: we Lema: we Morfema: we
# Lexema: are Lema: be Morfema: are
# Lexema: not Lema: not Morfema: not
# Lexema: enemies Lema: enemy Morfema: ies
# Lexema: but Lema: but Morfema: but
# Lexema: friends Lema: friend Morfema: nds
# Lexema: . Lema: . Morfema: .
# Lexema: Though Lema: though Morfema: ugh
# Lexema: passion Lema: passion Morfema: ion
# Lexema: may Lema: may Morfema: may
# Lexema: have Lema: have Morfema: ave
# Lexema: strained Lema: strain Morfema: ned
# Lexema: , Lema: , Morfema: ,
# Lexema: it Lema: it Morfema: it
# Lexema: must Lema: must Morfema: ust
# Lexema: not Lema: not Morfema: not
# Lexema: break Lema: break Morfema: eak
# Lexema: our Lema: our Morfema: our
# Lexema: bonds Lema: bond Morfema: nds
# Lexema: of Lema: of Morfema: of
# Lexema: affection Lema: affection Morfema: ion
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: And Lema: and Morfema: And
# Lexema: to Lema: to Morfema: to
# Lexema: those Lema: those Morfema: ose
# Lexema: Americans Lema: Americans Morfema: ans
# Lexema: whose Lema: whose Morfema: ose
# Lexema: support Lema: support Morfema: ort
# Lexema: I Lema: I Morfema: I
# Lexema: have Lema: have Morfema: ave
# Lexema: yet Lema: yet Morfema: yet
# Lexema: to Lema: to Morfema: to
# Lexema: earn Lema: earn Morfema: arn
# Lexema: , Lema: , Morfema: ,
# Lexema: I Lema: I Morfema: I
# Lexema: may Lema: may Morfema: may
# Lexema: not Lema: not Morfema: not
# Lexema: have Lema: have Morfema: ave
# Lexema: won Lema: win Morfema: won
# Lexema: your Lema: your Morfema: our
# Lexema: vote Lema: vote Morfema: ote
# Lexema: tonight Lema: tonight Morfema: ght
# Lexema: , Lema: , Morfema: ,
# Lexema: but Lema: but Morfema: but
# Lexema: I Lema: I Morfema: I
# Lexema: hear Lema: hear Morfema: ear
# Lexema: your Lema: your Morfema: our
# Lexema: voices Lema: voice Morfema: ces
# Lexema: . Lema: . Morfema: .
# Lexema: I Lema: I Morfema: I
# Lexema: need Lema: need Morfema: eed
# Lexema: your Lema: your Morfema: our
# Lexema: help Lema: help Morfema: elp
# Lexema: . Lema: . Morfema: .
# Lexema: And Lema: and Morfema: And
# Lexema: I Lema: I Morfema: I
# Lexema: will Lema: will Morfema: ill
# Lexema: be Lema: be Morfema: be
# Lexema: your Lema: your Morfema: our
# Lexema: president Lema: president Morfema: ent
# Lexema: , Lema: , Morfema: ,
# Lexema: too Lema: too Morfema: too
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: And Lema: and Morfema: And
# Lexema: to Lema: to Morfema: to
# Lexema: all Lema: all Morfema: all
# Lexema: those Lema: those Morfema: ose
# Lexema: watching Lema: watch Morfema: ing
# Lexema: tonight Lema: tonight Morfema: ght
# Lexema: from Lema: from Morfema: rom
# Lexema: beyond Lema: beyond Morfema: ond
# Lexema: our Lema: our Morfema: our
# Lexema: shores Lema: shore Morfema: res
# Lexema: , Lema: , Morfema: ,
# Lexema: from Lema: from Morfema: rom
# Lexema: parliaments Lema: parliament Morfema: nts
# Lexema: and Lema: and Morfema: and
# Lexema: palaces Lema: palace Morfema: ces
# Lexema: , Lema: , Morfema: ,
# Lexema: to Lema: to Morfema: to
# Lexema: those Lema: those Morfema: ose
# Lexema: who Lema: who Morfema: who
# Lexema: are Lema: be Morfema: are
# Lexema: huddled Lema: huddle Morfema: led
# Lexema: around Lema: around Morfema: und
# Lexema: radios Lema: radio Morfema: ios
# Lexema: in Lema: in Morfema: in
# Lexema: the Lema: the Morfema: the
# Lexema: forgotten Lema: forget Morfema: ten
# Lexema: corners Lema: corner Morfema: ers
# Lexema: of Lema: of Morfema: of
# Lexema: the Lema: the Morfema: the
# Lexema: world Lema: world Morfema: rld
# Lexema: , Lema: , Morfema: ,
# Lexema: our Lema: our Morfema: our
# Lexema: stories Lema: story Morfema: ies
# Lexema: are Lema: be Morfema: are
# Lexema: singular Lema: singular Morfema: lar
# Lexema: , Lema: , Morfema: ,
# Lexema: but Lema: but Morfema: but
# Lexema: our Lema: our Morfema: our
# Lexema: destiny Lema: destiny Morfema: iny
# Lexema: is Lema: be Morfema: is
# Lexema: shared Lema: share Morfema: red
# Lexema: , Lema: , Morfema: ,
# Lexema: and Lema: and Morfema: and
# Lexema: a Lema: a Morfema: a
# Lexema: new Lema: new Morfema: new
# Lexema: dawn Lema: dawn Morfema: awn
# Lexema: of Lema: of Morfema: of
# Lexema: American Lema: american Morfema: can
# Lexema: leadership Lema: leadership Morfema: hip
# Lexema: is Lema: be Morfema: is
# Lexema: at Lema: at Morfema: at
# Lexema: hand Lema: hand Morfema: and
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: To Lema: to Morfema: To
# Lexema: those Lema: those Morfema: ose
# Lexema: — Lema: — Morfema: —
# Lexema: to Lema: to Morfema: to
# Lexema: those Lema: those Morfema: ose
# Lexema: who Lema: who Morfema: who
# Lexema: would Lema: would Morfema: uld
# Lexema: tear Lema: tear Morfema: ear
# Lexema: the Lema: the Morfema: the
# Lexema: world Lema: world Morfema: rld
# Lexema: down Lema: down Morfema: own
# Lexema: : Lema: : Morfema: :
# Lexema: We Lema: we Morfema: We
# Lexema: will Lema: will Morfema: ill
# Lexema: defeat Lema: defeat Morfema: eat
# Lexema: you Lema: you Morfema: you
# Lexema: . Lema: . Morfema: .
# Lexema: To Lema: to Morfema: To
# Lexema: those Lema: those Morfema: ose
# Lexema: who Lema: who Morfema: who
# Lexema: seek Lema: seek Morfema: eek
# Lexema: peace Lema: peace Morfema: ace
# Lexema: and Lema: and Morfema: and
# Lexema: security Lema: security Morfema: ity
# Lexema: : Lema: : Morfema: :
# Lexema: We Lema: we Morfema: We
# Lexema: support Lema: support Morfema: ort
# Lexema: you Lema: you Morfema: you
# Lexema: . Lema: . Morfema: .
# Lexema: And Lema: and Morfema: And
# Lexema: to Lema: to Morfema: to
# Lexema: all Lema: all Morfema: all
# Lexema: those Lema: those Morfema: ose
# Lexema: who Lema: who Morfema: who
# Lexema: have Lema: have Morfema: ave
# Lexema: wondered Lema: wonder Morfema: red
# Lexema: if Lema: if Morfema: if
# Lexema: America Lema: America Morfema: ica
# Lexema: ’s Lema: ’s Morfema: ’s
# Lexema: beacon Lema: beacon Morfema: con
# Lexema: still Lema: still Morfema: ill
# Lexema: burns Lema: burn Morfema: rns
# Lexema: as Lema: as Morfema: as
# Lexema: bright Lema: bright Morfema: ght
# Lexema: : Lema: : Morfema: :
# Lexema: Tonight Lema: tonight Morfema: ght
# Lexema: we Lema: we Morfema: we
# Lexema: proved Lema: prove Morfema: ved
# Lexema: once Lema: once Morfema: nce
# Lexema: more Lema: more Morfema: ore
# Lexema: that Lema: that Morfema: hat
# Lexema: the Lema: the Morfema: the
# Lexema: true Lema: true Morfema: rue
# Lexema: strength Lema: strength Morfema: gth
# Lexema: of Lema: of Morfema: of
# Lexema: our Lema: our Morfema: our
# Lexema: nation Lema: nation Morfema: ion
# Lexema: comes Lema: come Morfema: mes
# Lexema: not Lema: not Morfema: not
# Lexema: from Lema: from Morfema: rom
# Lexema: the Lema: the Morfema: the
# Lexema: might Lema: might Morfema: ght
# Lexema: of Lema: of Morfema: of
# Lexema: our Lema: our Morfema: our
# Lexema: arms Lema: arm Morfema: rms
# Lexema: or Lema: or Morfema: or
# Lexema: the Lema: the Morfema: the
# Lexema: scale Lema: scale Morfema: ale
# Lexema: of Lema: of Morfema: of
# Lexema: our Lema: our Morfema: our
# Lexema: wealth Lema: wealth Morfema: lth
# Lexema: , Lema: , Morfema: ,
# Lexema: but Lema: but Morfema: but
# Lexema: from Lema: from Morfema: rom
# Lexema: the Lema: the Morfema: the
# Lexema: enduring Lema: endure Morfema: ing
# Lexema: power Lema: power Morfema: wer
# Lexema: of Lema: of Morfema: of
# Lexema: our Lema: our Morfema: our
# Lexema: ideals Lema: ideal Morfema: als
# Lexema: : Lema: : Morfema: :
# Lexema: democracy Lema: democracy Morfema: acy
# Lexema: , Lema: , Morfema: ,
# Lexema: liberty Lema: liberty Morfema: rty
# Lexema: , Lema: , Morfema: ,
# Lexema: opportunity Lema: opportunity Morfema: ity
# Lexema: and Lema: and Morfema: and
# Lexema: unyielding Lema: unyielde Morfema: ing
# Lexema: hope Lema: hope Morfema: ope
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: That Lema: that Morfema: hat
# Lexema: ’s Lema: ’ Morfema: ’s
# Lexema: the Lema: the Morfema: the
# Lexema: true Lema: true Morfema: rue
# Lexema: genius Lema: genius Morfema: ius
# Lexema: of Lema: of Morfema: of
# Lexema: America Lema: America Morfema: ica
# Lexema: : Lema: : Morfema: :
# Lexema: that Lema: that Morfema: hat
# Lexema: America Lema: America Morfema: ica
# Lexema: can Lema: can Morfema: can
# Lexema: change Lema: change Morfema: nge
# Lexema: . Lema: . Morfema: .
# Lexema: Our Lema: our Morfema: Our
# Lexema: union Lema: union Morfema: ion
# Lexema: can Lema: can Morfema: can
# Lexema: be Lema: be Morfema: be
# Lexema: perfected Lema: perfect Morfema: ted
# Lexema: . Lema: . Morfema: .
# Lexema: What Lema: what Morfema: hat
# Lexema: we Lema: we Morfema: we
# Lexema: ’ve Lema: ’ve Morfema: ’ve
# Lexema: already Lema: already Morfema: ady
# ...
# Lexema: hope Lema: hope Morfema: ope
# Lexema: ; Lema: ; Morfema: ;
# Lexema: the Lema: the Morfema: the
# Lexema: struggle Lema: struggle Morfema: gle
# Lexema: and Lema: and Morfema: and
# Lexema: the Lema: the Morfema: the
# Lexema: progress Lema: progress Morfema: ess
# Lexema: ; Lema: ; Morfema: ;
# Lexema: the Lema: the Morfema: the
# Lexema: times Lema: time Morfema: mes
# Lexema: we Lema: we Morfema: we
# Lexema: were Lema: be Morfema: ere
# Lexema: told Lema: tell Morfema: old
# Lexema: that Lema: that Morfema: hat
# Lexema: we Lema: we Morfema: we
# Lexema: ca Lema: can Morfema: ca
# Lexema: n’t Lema: n’t Morfema: n’t
# Lexema: , Lema: , Morfema: ,
# Lexema: and Lema: and Morfema: and
# Lexema: the Lema: the Morfema: the
# Lexema: people Lema: people Morfema: ple
# Lexema: who Lema: who Morfema: who
# Lexema: pressed Lema: press Morfema: sed
# Lexema: on Lema: on Morfema: on
# Lexema: with Lema: with Morfema: ith
# Lexema: that Lema: that Morfema: hat
# Lexema: American Lema: american Morfema: can
# Lexema: creed Lema: creed Morfema: eed
# Lexema: : Lema: : Morfema: :
# Lexema: Yes Lema: yes Morfema: Yes
# Lexema: we Lema: we Morfema: we
# Lexema: can Lema: can Morfema: can
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: At Lema: at Morfema: At
# Lexema: a Lema: a Morfema: a
# Lexema: time Lema: time Morfema: ime
# Lexema: when Lema: when Morfema: hen
# Lexema: women Lema: woman Morfema: men
# Lexema: ’s Lema: ’s Morfema: ’s
# Lexema: voices Lema: voice Morfema: ces
# Lexema: were Lema: be Morfema: ere
# Lexema: silenced Lema: silence Morfema: ced
# Lexema: and Lema: and Morfema: and
# Lexema: their Lema: their Morfema: eir
# Lexema: hopes Lema: hope Morfema: pes
# Lexema: dismissed Lema: dismiss Morfema: sed
# Lexema: , Lema: , Morfema: ,
# Lexema: she Lema: she Morfema: she
# Lexema: lived Lema: live Morfema: ved
# Lexema: to Lema: to Morfema: to
# Lexema: see Lema: see Morfema: see
# Lexema: them Lema: they Morfema: hem
# Lexema: stand Lema: stand Morfema: and
# Lexema: up Lema: up Morfema: up
# Lexema: and Lema: and Morfema: and
# Lexema: speak Lema: speak Morfema: eak
# Lexema: out Lema: out Morfema: out
# Lexema: and Lema: and Morfema: and
# Lexema: reach Lema: reach Morfema: ach
# Lexema: for Lema: for Morfema: for
# Lexema: the Lema: the Morfema: the
# Lexema: ballot Lema: ballot Morfema: lot
# Lexema: . Lema: . Morfema: .
# Lexema: Yes Lema: yes Morfema: Yes
# Lexema: we Lema: we Morfema: we
# Lexema: can Lema: can Morfema: can
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: When Lema: when Morfema: hen
# Lexema: there Lema: there Morfema: ere
# Lexema: was Lema: be Morfema: was
# Lexema: despair Lema: despair Morfema: air
# Lexema: in Lema: in Morfema: in
# Lexema: the Lema: the Morfema: the
# Lexema: dust Lema: dust Morfema: ust
# Lexema: bowl Lema: bowl Morfema: owl
# Lexema: and Lema: and Morfema: and
# Lexema: depression Lema: depression Morfema: ion
# Lexema: across Lema: across Morfema: oss
# Lexema: the Lema: the Morfema: the
# Lexema: land Lema: land Morfema: and
# Lexema: , Lema: , Morfema: ,
# Lexema: she Lema: she Morfema: she
# Lexema: saw Lema: see Morfema: saw
# Lexema: a Lema: a Morfema: a
# Lexema: nation Lema: nation Morfema: ion
# Lexema: conquer Lema: conquer Morfema: uer
# Lexema: fear Lema: fear Morfema: ear
# Lexema: itself Lema: itself Morfema: elf
# Lexema: with Lema: with Morfema: ith
# Lexema: a Lema: a Morfema: a
# Lexema: New Lema: New Morfema: New
# Lexema: Deal Lema: Deal Morfema: eal
# Lexema: , Lema: , Morfema: ,
# Lexema: new Lema: new Morfema: new
# Lexema: jobs Lema: job Morfema: obs
# Lexema: , Lema: , Morfema: ,
# Lexema: a Lema: a Morfema: a
# Lexema: new Lema: new Morfema: new
# Lexema: sense Lema: sense Morfema: nse
# Lexema: of Lema: of Morfema: of
# Lexema: common Lema: common Morfema: mon
# Lexema: purpose Lema: purpose Morfema: ose
# Lexema: . Lema: . Morfema: .
# Lexema: Yes Lema: yes Morfema: Yes
# Lexema: we Lema: we Morfema: we
# Lexema: can Lema: can Morfema: can
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: When Lema: when Morfema: hen
# Lexema: the Lema: the Morfema: the
# Lexema: bombs Lema: bomb Morfema: mbs
# Lexema: fell Lema: fall Morfema: ell
# Lexema: on Lema: on Morfema: on
# Lexema: our Lema: our Morfema: our
# Lexema: harbor Lema: harbor Morfema: bor
# Lexema: and Lema: and Morfema: and
# Lexema: tyranny Lema: tyranny Morfema: nny
# Lexema: threatened Lema: threaten Morfema: ned
# Lexema: the Lema: the Morfema: the
# Lexema: world Lema: world Morfema: rld
# Lexema: , Lema: , Morfema: ,
# Lexema: she Lema: she Morfema: she
# Lexema: was Lema: be Morfema: was
# Lexema: there Lema: there Morfema: ere
# Lexema: to Lema: to Morfema: to
# Lexema: witness Lema: witness Morfema: ess
# Lexema: a Lema: a Morfema: a
# Lexema: generation Lema: generation Morfema: ion
# Lexema: rise Lema: rise Morfema: ise
# Lexema: to Lema: to Morfema: to
# Lexema: greatness Lema: greatness Morfema: ess
# Lexema: and Lema: and Morfema: and
# Lexema: a Lema: a Morfema: a
# Lexema: democracy Lema: democracy Morfema: acy
# Lexema: was Lema: be Morfema: was
# Lexema: saved Lema: save Morfema: ved
# Lexema: . Lema: . Morfema: .
# Lexema: Yes Lema: yes Morfema: Yes
# Lexema: we Lema: we Morfema: we
# Lexema: can Lema: can Morfema: can
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: She Lema: she Morfema: She
# Lexema: was Lema: be Morfema: was
# Lexema: there Lema: there Morfema: ere
# Lexema: for Lema: for Morfema: for
# Lexema: the Lema: the Morfema: the
# Lexema: buses Lema: bus Morfema: ses
# Lexema: in Lema: in Morfema: in
# Lexema: Montgomery Lema: Montgomery Morfema: ery
# Lexema: , Lema: , Morfema: ,
# Lexema: the Lema: the Morfema: the
# Lexema: hoses Lema: hose Morfema: ses
# Lexema: in Lema: in Morfema: in
# Lexema: Birmingham Lema: Birmingham Morfema: ham
# Lexema: , Lema: , Morfema: ,
# Lexema: a Lema: a Morfema: a
# Lexema: bridge Lema: bridge Morfema: dge
# Lexema: in Lema: in Morfema: in
# Lexema: Selma Lema: Selma Morfema: lma
# Lexema: , Lema: , Morfema: ,
# Lexema: and Lema: and Morfema: and
# Lexema: a Lema: a Morfema: a
# Lexema: preacher Lema: preacher Morfema: her
# Lexema: from Lema: from Morfema: rom
# Lexema: Atlanta Lema: Atlanta Morfema: nta
# Lexema: who Lema: who Morfema: who
# Lexema: told Lema: tell Morfema: old
# Lexema: a Lema: a Morfema: a
# Lexema: people Lema: people Morfema: ple
# Lexema: that Lema: that Morfema: hat
# Lexema: “ Lema: " Morfema: “
# Lexema: We Lema: we Morfema: We
# Lexema: Shall Lema: shall Morfema: all
# Lexema: Overcome Lema: overcome Morfema: ome
# Lexema: . Lema: . Morfema: .
# Lexema: ” Lema: " Morfema: ”
# Lexema: Yes Lema: yes Morfema: Yes
# Lexema: we Lema: we Morfema: we
# Lexema: can Lema: can Morfema: can
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: A Lema: a Morfema: A
# Lexema: man Lema: man Morfema: man
# Lexema: touched Lema: touch Morfema: hed
# Lexema: down Lema: down Morfema: own
# Lexema: on Lema: on Morfema: on
# Lexema: the Lema: the Morfema: the
# Lexema: moon Lema: moon Morfema: oon
# Lexema: , Lema: , Morfema: ,
# Lexema: a Lema: a Morfema: a
# Lexema: wall Lema: wall Morfema: all
# Lexema: came Lema: come Morfema: ame
# Lexema: down Lema: down Morfema: own
# Lexema: in Lema: in Morfema: in
# Lexema: Berlin Lema: Berlin Morfema: lin
# Lexema: , Lema: , Morfema: ,
# Lexema: a Lema: a Morfema: a
# Lexema: world Lema: world Morfema: rld
# Lexema: was Lema: be Morfema: was
# Lexema: connected Lema: connect Morfema: ted
# Lexema: by Lema: by Morfema: by
# Lexema: our Lema: our Morfema: our
# Lexema: own Lema: own Morfema: own
# Lexema: science Lema: science Morfema: nce
# Lexema: and Lema: and Morfema: and
# Lexema: imagination Lema: imagination Morfema: ion
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: And Lema: and Morfema: And
# Lexema: this Lema: this Morfema: his
# Lexema: year Lema: year Morfema: ear
# Lexema: , Lema: , Morfema: ,
# Lexema: in Lema: in Morfema: in
# Lexema: this Lema: this Morfema: his
# Lexema: election Lema: election Morfema: ion
# Lexema: , Lema: , Morfema: ,
# Lexema: she Lema: she Morfema: she
# Lexema: touched Lema: touch Morfema: hed
# Lexema: her Lema: her Morfema: her
# Lexema: finger Lema: finger Morfema: ger
# Lexema: to Lema: to Morfema: to
# Lexema: a Lema: a Morfema: a
# Lexema: screen Lema: screen Morfema: een
# Lexema: , Lema: , Morfema: ,
# Lexema: and Lema: and Morfema: and
# Lexema: cast Lema: cast Morfema: ast
# Lexema: her Lema: her Morfema: her
# Lexema: vote Lema: vote Morfema: ote
# Lexema: , Lema: , Morfema: ,
# Lexema: because Lema: because Morfema: use
# Lexema: after Lema: after Morfema: ter
# Lexema: 106 Lema: 106 Morfema: 106
# Lexema: years Lema: year Morfema: ars
# Lexema: in Lema: in Morfema: in
# Lexema: America Lema: America Morfema: ica
# Lexema: , Lema: , Morfema: ,
# Lexema: through Lema: through Morfema: ugh
# Lexema: the Lema: the Morfema: the
# Lexema: best Lema: good Morfema: est
# Lexema: of Lema: of Morfema: of
# Lexema: times Lema: time Morfema: mes
# Lexema: and Lema: and Morfema: and
# Lexema: the Lema: the Morfema: the
# Lexema: darkest Lema: darkest Morfema: est
# Lexema: of Lema: of Morfema: of
# Lexema: hours Lema: hour Morfema: urs
# Lexema: , Lema: , Morfema: ,
# Lexema: she Lema: she Morfema: she
# Lexema: knows Lema: know Morfema: ows
# Lexema: how Lema: how Morfema: how
# Lexema: America Lema: America Morfema: ica
# Lexema: can Lema: can Morfema: can
# Lexema: change Lema: change Morfema: nge
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: Yes Lema: yes Morfema: Yes
# Lexema: we Lema: we Morfema: we
# Lexema: can Lema: can Morfema: can
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: America Lema: America Morfema: ica
# Lexema: , Lema: , Morfema: ,
# Lexema: we Lema: we Morfema: we
# Lexema: have Lema: have Morfema: ave
# Lexema: come Lema: come Morfema: ome
# Lexema: so Lema: so Morfema: so
# Lexema: far Lema: far Morfema: far
# Lexema: . Lema: . Morfema: .
# Lexema: We Lema: we Morfema: We
# Lexema: have Lema: have Morfema: ave
# Lexema: seen Lema: see Morfema: een
# Lexema: so Lema: so Morfema: so
# Lexema: much Lema: much Morfema: uch
# Lexema: . Lema: . Morfema: .
# Lexema: But Lema: but Morfema: But
# Lexema: there Lema: there Morfema: ere
# Lexema: is Lema: be Morfema: is
# Lexema: so Lema: so Morfema: so
# Lexema: much Lema: much Morfema: uch
# Lexema: more Lema: more Morfema: ore
# Lexema: to Lema: to Morfema: to
# Lexema: do Lema: do Morfema: do
# Lexema: . Lema: . Morfema: .
# Lexema: So Lema: so Morfema: So
# Lexema: tonight Lema: tonight Morfema: ght
# Lexema: , Lema: , Morfema: ,
# Lexema: let Lema: let Morfema: let
# Lexema: us Lema: we Morfema: us
# Lexema: ask Lema: ask Morfema: ask
# Lexema: ourselves Lema: ourselves Morfema: ves
# Lexema: — Lema: — Morfema: —
# Lexema: if Lema: if Morfema: if
# Lexema: our Lema: our Morfema: our
# Lexema: children Lema: child Morfema: ren
# Lexema: should Lema: should Morfema: uld
# Lexema: live Lema: live Morfema: ive
# Lexema: to Lema: to Morfema: to
# Lexema: see Lema: see Morfema: see
# Lexema: the Lema: the Morfema: the
# Lexema: next Lema: next Morfema: ext
# Lexema: century Lema: century Morfema: ury
# Lexema: ; Lema: ; Morfema: ;
# Lexema: if Lema: if Morfema: if
# Lexema: my Lema: my Morfema: my
# Lexema: daughters Lema: daughter Morfema: ers
# Lexema: should Lema: should Morfema: uld
# Lexema: be Lema: be Morfema: be
# Lexema: so Lema: so Morfema: so
# Lexema: lucky Lema: lucky Morfema: cky
# Lexema: to Lema: to Morfema: to
# Lexema: live Lema: live Morfema: ive
# Lexema: as Lema: as Morfema: as
# Lexema: long Lema: long Morfema: ong
# Lexema: as Lema: as Morfema: as
# Lexema: Ann Lema: Ann Morfema: Ann
# Lexema: Nixon Lema: Nixon Morfema: xon
# Lexema: Cooper Lema: Cooper Morfema: per
# Lexema: , Lema: , Morfema: ,
# Lexema: what Lema: what Morfema: hat
# Lexema: change Lema: change Morfema: nge
# Lexema: will Lema: will Morfema: ill
# Lexema: they Lema: they Morfema: hey
# Lexema: see Lema: see Morfema: see
# Lexema: ? Lema: ? Morfema: ?
# Lexema: What Lema: what Morfema: hat
# Lexema: progress Lema: progress Morfema: ess
# Lexema: will Lema: will Morfema: ill
# Lexema: we Lema: we Morfema: we
# Lexema: have Lema: have Morfema: ave
# Lexema: made Lema: make Morfema: ade
# Lexema: ? Lema: ? Morfema: ?
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: This Lema: this Morfema: his
# Lexema: is Lema: be Morfema: is
# Lexema: our Lema: our Morfema: our
# Lexema: chance Lema: chance Morfema: nce
# Lexema: to Lema: to Morfema: to
# Lexema: answer Lema: answer Morfema: wer
# Lexema: that Lema: that Morfema: hat
# Lexema: call Lema: call Morfema: all
# Lexema: . Lema: . Morfema: .
# Lexema: This Lema: this Morfema: his
# Lexema: is Lema: be Morfema: is
# Lexema: our Lema: our Morfema: our
# Lexema: moment Lema: moment Morfema: ent
# Lexema: . Lema: . Morfema: .
# Lexema:
#  Lema:
#  Morfema:
#
# Lexema: This Lema: this Morfema: his
# Lexema: is Lema: be Morfema: is
# Lexema: our Lema: our Morfema: our
# Lexema: time Lema: time Morfema: ime
# Lexema: , Lema: , Morfema: ,
# Lexema: to Lema: to Morfema: to
# Lexema: put Lema: put Morfema: put
# Lexema: our Lema: our Morfema: our
# Lexema: people Lema: people Morfema: ple
# Lexema: back Lema: back Morfema: ack
# Lexema: to Lema: to Morfema: to
# Lexema: work Lema: work Morfema: ork
# Lexema: and Lema: and Morfema: and
# Lexema: open Lema: open Morfema: pen
# Lexema: doors Lema: door Morfema: ors
# Lexema: of Lema: of Morfema: of
# Lexema: opportunity Lema: opportunity Morfema: ity
# Lexema: for Lema: for Morfema: for
# Lexema: our Lema: our Morfema: our
# Lexema: kids Lema: kid Morfema: ids
# Lexema: ; Lema: ; Morfema: ;
# Lexema: to Lema: to Morfema: to
# Lexema: restore Lema: restore Morfema: ore
# Lexema: prosperity Lema: prosperity Morfema: ity
# Lexema: and Lema: and Morfema: and
# Lexema: promote Lema: promote Morfema: ote
# Lexema: the Lema: the Morfema: the
# Lexema: cause Lema: cause Morfema: use
# Lexema: of Lema: of Morfema: of
# Lexema: peace Lema: peace Morfema: ace
# Lexema: ; Lema: ; Morfema: ;
# Lexema: to Lema: to Morfema: to
# Lexema: reclaim Lema: reclaim Morfema: aim
# Lexema: the Lema: the Morfema: the
# Lexema: American Lema: american Morfema: can
# Lexema: dream Lema: dream Morfema: eam
# Lexema: and Lema: and Morfema: and
# Lexema: reaffirm Lema: reaffirm Morfema: irm
# Lexema: that Lema: that Morfema: hat
# Lexema: fundamental Lema: fundamental Morfema: tal
# Lexema: truth Lema: truth Morfema: uth
# Lexema: , Lema: , Morfema: ,
# Lexema: that Lema: that Morfema: hat
# Lexema: , Lema: , Morfema: ,
# Lexema: out Lema: out Morfema: out
# Lexema: of Lema: of Morfema: of
# Lexema: many Lema: many Morfema: any
# Lexema: , Lema: , Morfema: ,
# Lexema: we Lema: we Morfema: we
# Lexema: are Lema: be Morfema: are
# Lexema: one Lema: one Morfema: one
# Lexema: ; Lema: ; Morfema: ;
# Lexema: that Lema: that Morfema: hat
# Lexema: while Lema: while Morfema: ile
# Lexema: we Lema: we Morfema: we
# Lexema: breathe Lema: breathe Morfema: the
# Lexema: , Lema: , Morfema: ,
# Lexema: we Lema: we Morfema: we
# Lexema: hope Lema: hope Morfema: ope
# Lexema: . Lema: . Morfema: .
# Lexema: And Lema: and Morfema: And
# Lexema: where Lema: where Morfema: ere
# Lexema: we Lema: we Morfema: we
# Lexema: are Lema: be Morfema: are
# Lexema: met Lema: meet Morfema: met
# Lexema: with Lema: with Morfema: ith
# Lexema: cynicism Lema: cynicism Morfema: ism
# Lexema: and Lema: and Morfema: and
# Lexema: doubts Lema: doubt Morfema: bts
# Lexema: and Lema: and Morfema: and
# Lexema: those Lema: those Morfema: ose
# Lexema: who Lema: who Morfema: who
# Lexema: tell Lema: tell Morfema: ell
# Lexema: us Lema: we Morfema: us
# Lexema: that Lema: that Morfema: hat
# Lexema: we Lema: we Morfema: we
# Lexema: ca Lema: can Morfema: ca
# Lexema: n’t Lema: not Morfema: n’t
# Lexema: , Lema: , Morfema: ,
# Lexema: we Lema: we Morfema: we
# Lexema: will Lema: will Morfema: ill
# Lexema: respond Lema: respond Morfema: ond
# Lexema: with Lema: with Morfema: ith
# Lexema: that Lema: that Morfema: hat
# Lexema: timeless Lema: timeless Morfema: ess
# Lexema: creed Lema: creed Morfema: eed
# Lexema: that Lema: that Morfema: hat
# Lexema: sums Lema: sum Morfema: ums
# Lexema: up Lema: up Morfema: up
# Lexema: the Lema: the Morfema: the
# Lexema: spirit Lema: spirit Morfema: rit
# Lexema: of Lema: of Morfema: of
# Lexema: a Lema: a Morfema: a
# Lexema: people Lema: people Morfema: ple
# Lexema: : Lema: : Morfema: :
# Lexema: Yes Lema: yes Morfema: Yes
# Lexema: , Lema: , Morfema: ,
# Lexema: we Lema: we Morfema: we
# Lexema: can Lema: can Morfema: can
# Lexema: . Lema: . Morfema: .
# Lexema: [ Lema: [ Morfema: [

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>
#
# Iterando en los token del texto se puede acceder a los atributos lex, lemma_ y morph, que obiene la información morfológica del token. Como en nuestro caso, solo tenemos que obtener el morfema, entiendo que sería suficiente con el atributo suffix_.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 5.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Cómo puedes identificar/eliminar las stop words?</span>

# %%
token_list = []
for token in doc:
    token_list.append(token.text)

token_list_no_stopwords =[]

for word in token_list:
    lexeme = nlp.vocab[word]
    if not lexeme.is_stop:
        token_list_no_stopwords.append(word)
print(len(token_list))
print(len(token_list_no_stopwords))
# Out:
# 1939
# 906

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>
#
# Recorro los tokens para crear una lista. A continuación, recorro la lista de tokens y compruebo si el token es una stop word. Si no lo es, lo añado a la lista de tokens sin stop words. Así obtengo las dos listas, la de tokens, y la de tokens filtrada sin stopwords.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 6.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Qué atributo del token contiene la etiqueta NER?</span>

# %%
for token in doc:
    print(token.text, token.ent_type_)

for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# “
# Hello
# ,
# Chicago GPE
# .
#
#
# If
# there
# is
# anyone
# out
# there
# who
# still
# doubts
# that
# America GPE
# is
# a
# place
# where
# all
# things
# are
# possible
# ,
# who
# still
# wonders
# if
# the
# dream
# of
# our
# founders
# is
# alive
# in
# our
# time
# ,
# who
# still
# questions
# the
# power
# of
# our
# democracy
# ,
# tonight TIME
# is
# your
# answer
# .
#
#
# It
# ’s
# the
# answer
# told
# by
# lines
# that
# stretched
# around
# schools
# and
# churches
# in
# numbers
# this
# nation
# has
# never
# seen
# ,
# by
# people
# who
# waited
# three TIME
# hours TIME
# and
# four TIME
# hours TIME
# ,
# many
# for
# the
# first ORDINAL
# time
# in
# their
# lives
# ,
# because
# they
# believed
# that
# this
# time
# must
# be
# different
# ,
# that
# their
# voices
# could
# be
# that
# difference
# .
#
#
# It
# ’s
# the
# answer
# spoken
# by
# young
# and
# old
# ,
# rich
# and
# poor
# ,
# Democrat NORP
# and
# Republican NORP
# ,
# black
# ,
# white
# ,
# Hispanic NORP
# ,
# Asian NORP
# ,
# Native NORP
# American NORP
# ,
# gay
# ,
# straight
# ,
# disabled
# and
# not
# disabled
# .
# Americans NORP
# who
# sent
# a
# message
# to
# the
# world
# that
# we
# have
# never
# been
# just
# a
# collection
# of
# individuals
# or
# a
# collection
# of
# red
# states
# and
# blue
# states
# .
#
#
# We
# are
# ,
# and
# always
# will
# be
# ,
# the GPE
# United GPE
# States GPE
# of GPE
# America GPE
# .
#
#
# It
# ’s
# the
# answer
# that
# led
# those
# who
# ’ve
# been
# told
# for
# so
# long
# by
# so
# many
# to
# be
# cynical
# and
# fearful
# and
# doubtful
# about
# what
# we
# can
# achieve
# to
# put
# their
# hands
# on
# the
# arc
# of
# history
# and
# bend
# it
# once
# more
# toward
# the
# hope
# of
# a
# better
# day
# .
#
#
# It
# ’s
# been
# a
# long
# time
# coming
# ,
# but
# tonight TIME
# ,
# because
# of
# what
# we
# did
# on
# this
# date
# in
# this
# election
# at
# this
# defining
# moment
# change
# has
# come
# to
# America GPE
# .
#
#
# [
# read
# more
# ]
#
#
#
# We
# did
# n’t
# start
# with
# much
# money
# or
# many
# endorsements
# .
# Our
# campaign
# was
# not
# hatched
# in
# the
# halls
# of
# Washington GPE
# .
# It
# began
# in
# the
# backyards
# of
# Des GPE
# Moines GPE
# and
# the
# living
# rooms
# of
# Concord GPE
# and
# the
# front
# porches
# of
# Charleston GPE
# .
# It
# was
# built
# by
# working
# men
# and
# women
# who
# dug
# into
# what
# little
# savings
# they
# had
# to
# give
# $ MONEY
# 5 MONEY
# and MONEY
# $ MONEY
# 10 MONEY
# and MONEY
# $ MONEY
# 20 MONEY
# to
# the
# cause
# .
#
#
# It
# grew
# strength
# from
# the
# young
# people
# who
# rejected
# the
# myth
# of
# their
# generation
# ’s
# apathy
# who
# left
# their
# homes
# and
# their
# families
# for
# jobs
# that
# offered
# little
# pay
# and
# less
# sleep
# .
#
#
# It
# drew
# strength
# from
# the
# not
# -
# so
# -
# young
# people
# who
# braved
# the
# bitter
# cold
# and
# scorching
# heat
# to
# knock
# on
# doors
# of
# perfect
# strangers
# ,
# and
# from
# the
# millions CARDINAL
# of
# Americans NORP
# who
# volunteered
# and
# organized
# and
# proved
# that
# more DATE
# than DATE
# two DATE
# centuries DATE
# later DATE
# a
# government
# of
# the
# people
# ,
# by
# the
# people
# ,
# and
# for
# the
# people
# has
# not
# perished
# from
# the
# Earth LOC
# .
#
#
# This
# is
# your
# victory
# .
#
#
# And
# I
# know
# you
# did
# n’t
# do
# this
# just
# to
# win
# an
# election
# .
# And
# I
# know
# you
# did
# n’t
# do
# it
# for
# me
# .
#
#
# You
# did
# it
# because
# you
# understand
# the
# enormity
# of
# the
# task
# that
# lies
# ahead
# .
# For
# even
# as
# we
# celebrate
# tonight TIME
# ,
# we
# know
# the
# challenges
# that
# tomorrow DATE
# will
# bring
# are
# the
# greatest
# of
# our
# lifetime
# —
# two CARDINAL
# wars
# ,
# a
# planet
# in
# peril
# ,
# the
# worst
# financial
# crisis
# in
# a DATE
# century DATE
# .
#
#
# Even
# as
# we
# stand
# here
# tonight TIME
# ,
# we
# know
# there
# are
# brave
# Americans NORP
# waking
# up
# in
# the
# deserts
# of
# Iraq GPE
# and
# the
# mountains
# of
# Afghanistan GPE
# to
# risk
# their
# lives
# for
# us
# .
#
#
# There
# are
# mothers
# and
# fathers
# who
# will
# lie
# awake
# after
# the
# children
# fall
# asleep
# and
# wonder
# how
# they
# ’ll
# make
# the
# mortgage
# or
# pay
# their
# doctors
# ’
# bills
# or
# save
# enough
# for
# their
# child
# ’s
# college
# education
# .
#
#
# There
# ’s
# new
# energy
# to
# harness
# ,
# new
# jobs
# to
# be
# created
# ,
# new
# schools
# to
# build
# ,
# and
# threats
# to
# meet
# ,
# alliances
# to
# repair
# .
#
#
# The
# road
# ahead
# will
# be
# long
# .
# Our
# climb
# will
# be
# steep
# .
# We
# may
# not
# get
# there
# in
# one DATE
# year DATE
# or
# even
# in
# one CARDINAL
# term
# .
# But
# ,
# America GPE
# ,
# I
# have
# never
# been
# more
# hopeful
# than
# I
# am
# tonight TIME
# that
# we
# will
# get
# there
# .
#
#
# I
# promise
# you
# ,
# we
# as
# a
# people
# will
# get
# there
# .
#
#
# There
# will
# be
# setbacks
# and
# false
# starts
# .
# There
# are
# many
# who
# wo
# n’t
# agree
# with
# every
# decision
# or
# policy
# I
# make
# as
# president
# .
# And
# we
# know
# the
# government
# ca
# n’t
# solve
# every
# problem
# .
#
#
# But
# I
# will
# always
# be
# honest
# with
# you
# about
# the
# challenges
# we
# face
# .
# I
# will
# listen
# to
# you
# ,
# especially
# when
# we
# disagree
# .
# And
# ,
# above
# all
# ,
# I
# will
# ask
# you
# to
# join
# in
# the
# work
# of
# remaking
# this
# nation
# ,
# the
# only
# way
# it
# ’s
# been
# done
# in
# America GPE
# for
# 221 DATE
# years DATE
# —
# block
# by
# block
# ,
# brick
# by
# brick
# ,
# calloused
# hand
# by
# calloused
# hand
# .
#
#
# What
# began
# 21 DATE
# months DATE
# ago DATE
# in
# the
# depths
# of
# winter DATE
# can
# not
# end
# on
# this TIME
# autumn TIME
# night TIME
# .
#
#
# This
# victory
# alone
# is
# not
# the
# change
# we
# seek
# .
# It
# is
# only
# the
# chance
# for
# us
# to
# make
# that
# change
# .
# And
# that
# can
# not
# happen
# if
# we
# go
# back
# to
# the
# way
# things
# were
# .
#
#
# It
# ca
# n’t
# happen
# without
# you
# ,
# without
# a
# new
# spirit
# of
# service
# ,
# a
# new
# spirit
# of
# sacrifice
# .
#
#
# So
# let
# us
# summon
# a
# new
# spirit
# of
# patriotism
# ,
# of
# responsibility
# ,
# where
# each
# of
# us
# resolves
# to
# pitch
# in
# and
# work
# harder
# and
# look
# after
# not
# only
# ourselves
# but
# each
# other
# .
#
#
# Let
# us
# remember
# that
# ,
# if
# this
# financial
# crisis
# taught
# us
# anything
# ,
# it
# ’s
# that
# we
# can
# not
# have
# a
# thriving
# Wall
# Street
# while
# Main FAC
# Street FAC
# suffers
# .
#
#
# In
# this
# country
# ,
# we
# rise
# or
# fall
# as
# one CARDINAL
# nation
# ,
# as
# one CARDINAL
# people
# .
# Let
# ’s
# resist
# the
# temptation
# to
# fall
# back
# on
# the
# same
# partisanship
# and
# pettiness
# and
# immaturity
# that
# has
# poisoned
# our
# politics
# for
# so
# long
# .
#
#
# Let
# ’s
# remember
# that
# it
# was
# a
# man
# from
# this
# state
# who
# first ORDINAL
# carried
# the
# banner
# of
# the ORG
# Republican ORG
# Party ORG
# to
# the ORG
# White ORG
# House ORG
# ,
# a
# party
# founded
# on
# the
# values
# of
# self
# -
# reliance
# and
# individual
# liberty
# and
# national
# unity
# .
#
#
# Those
# are
# values
# that
# we
# all
# share
# .
# And
# while
# the ORG
# Democratic ORG
# Party ORG
# has
# won
# a
# great
# victory
# tonight TIME
# ,
# we
# do
# so
# with
# a
# measure
# of
# humility
# and
# determination
# to
# heal
# the
# divides
# that
# have
# held
# back
# our
# progress
# .
#
#
# As
# Lincoln ORG
# said
# to
# a
# nation
# far
# more
# divided
# than
# ours
# ,
# we
# are
# not
# enemies
# but
# friends
# .
# Though
# passion
# may
# have
# strained
# ,
# it
# must
# not
# break
# our
# bonds
# of
# affection
# .
#
#
# And
# to
# those
# Americans NORP
# whose
# support
# I
# have
# yet
# to
# earn
# ,
# I
# may
# not
# have
# won
# your
# vote
# tonight TIME
# ,
# but
# I
# hear
# your
# voices
# .
# I
# need
# your
# help
# .
# And
# I
# will
# be
# your
# president
# ,
# too
# .
#
#
# And
# to
# all
# those
# watching
# tonight TIME
# from
# beyond
# our
# shores
# ,
# from
# parliaments
# and
# palaces
# ,
# to
# those
# who
# are
# huddled
# around
# radios
# in
# the
# forgotten
# corners
# of
# the
# world
# ,
# our
# stories
# are
# singular
# ,
# but
# our
# destiny
# is
# shared
# ,
# and
# a
# new
# dawn
# of
# American NORP
# leadership
# is
# at
# hand
# .
#
#
# To
# those
# —
# to
# those
# who
# would
# tear
# the
# world
# down
# :
# We
# will
# defeat
# you
# .
# To
# those
# who
# seek
# peace
# and
# security
# :
# We
# support
# you
# .
# And
# to
# all
# those
# who
# have
# wondered
# if
# America GPE
# ’s
# beacon
# still
# burns
# as
# bright
# :
# Tonight TIME
# we
# proved
# once
# more
# that
# the
# true
# strength
# of
# our
# nation
# comes
# not
# from
# the
# might
# of
# our
# arms
# or
# the
# scale
# of
# our
# wealth
# ,
# but
# from
# the
# enduring
# power
# of
# our
# ideals
# :
# democracy
# ,
# liberty
# ,
# opportunity
# and
# unyielding
# hope
# .
#
#
# That
# ’s
# the
# true
# genius
# of
# America GPE
# :
# that
# America GPE
# can
# change
# .
# Our
# union
# can
# be
# perfected
# .
# What
# we
# ’ve
# already
# achieved
# gives
# us
# hope
# for
# what
# we
# can
# and
# must
# achieve
# tomorrow DATE
# .
#
#
# This
# election
# had
# many
# firsts
# and
# many
# stories
# that
# will
# be
# told
# for
# generations
# .
# But
# one
# that
# ’s
# on
# my
# mind
# tonight TIME
# ’s
# about
# a
# woman
# who
# cast
# her
# ballot
# in
# Atlanta GPE
# .
# She
# ’s
# a
# lot
# like
# the
# millions CARDINAL
# of
# others
# who
# stood
# in
# line
# to
# make
# their
# voice
# heard
# in
# this
# election
# except
# for
# one CARDINAL
# thing
# :
# Ann PERSON
# Nixon PERSON
# Cooper PERSON
# is
# 106 DATE
# years DATE
# old DATE
# .
#
#
# She
# was
# born
# just
# a
# generation
# past
# slavery
# ;
# a
# time
# when
# there
# were
# no
# cars
# on
# the
# road
# or
# planes
# in
# the
# sky
# ;
# when
# someone
# like
# her
# could
# n’t
# vote
# for
# two CARDINAL
# reasons
# —
# because
# she
# was
# a
# woman
# and
# because
# of
# the
# color
# of
# her
# skin
# .
#
#
# And
# tonight TIME
# ,
# I
# think
# about
# all
# that
# she
# ’s
# seen
# throughout
# her
# century
# in
# America GPE
# —
# the
# heartache
# and
# the
# hope
# ;
# the
# struggle
# and
# the
# progress
# ;
# the
# times
# we
# were
# told
# that
# we
# ca
# n’t
# ,
# and
# the
# people
# who
# pressed
# on
# with
# that
# American NORP
# creed
# :
# Yes
# we
# can
# .
#
#
# At
# a
# time
# when
# women
# ’s
# voices
# were
# silenced
# and
# their
# hopes
# dismissed
# ,
# she
# lived
# to
# see
# them
# stand
# up
# and
# speak
# out
# and
# reach
# for
# the
# ballot
# .
# Yes
# we
# can
# .
#
#
# When
# there
# was
# despair
# in
# the
# dust
# bowl
# and
# depression
# across
# the
# land
# ,
# she
# saw
# a
# nation
# conquer
# fear
# itself
# with
# a
# New
# Deal
# ,
# new
# jobs
# ,
# a
# new
# sense
# of
# common
# purpose
# .
# Yes
# we
# can
# .
#
#
# When
# the
# bombs
# fell
# on
# our
# harbor
# and
# tyranny
# threatened
# the
# world
# ,
# she
# was
# there
# to
# witness
# a
# generation
# rise
# to
# greatness
# and
# a
# democracy
# was
# saved
# .
# Yes
# we
# can
# .
#
#
# She
# was
# there
# for
# the
# buses
# in
# Montgomery ORG
# ,
# the
# hoses
# in
# Birmingham GPE
# ,
# a
# bridge
# in
# Selma GPE
# ,
# and
# a
# preacher
# from
# Atlanta GPE
# who
# told
# a
# people
# that
# “
# We
# Shall
# Overcome
# .
# ”
# Yes
# we
# can
# .
#
#
# A
# man
# touched
# down
# on
# the LOC
# moon LOC
# ,
# a
# wall
# came
# down
# in
# Berlin GPE
# ,
# a
# world
# was
# connected
# by
# our
# own
# science
# and
# imagination
# .
#
#
# And
# this DATE
# year DATE
# ,
# in
# this
# election
# ,
# she
# touched
# her
# finger
# to
# a
# screen
# ,
# and
# cast
# her
# vote
# ,
# because
# after
# 106 DATE
# years DATE
# in
# America GPE
# ,
# through
# the
# best
# of
# times
# and
# the
# darkest
# of
# hours TIME
# ,
# she
# knows
# how
# America GPE
# can
# change
# .
#
#
# Yes
# we
# can
# .
#
#
# America GPE
# ,
# we
# have
# come
# so
# far
# .
# We
# have
# seen
# so
# much
# .
# But
# there
# is
# so
# much
# more
# to
# do
# .
# So
# tonight TIME
# ,
# let
# us
# ask
# ourselves
# —
# if
# our
# children
# should
# live
# to
# see
# the DATE
# next DATE
# century DATE
# ;
# if
# my
# daughters
# should
# be
# so
# lucky
# to
# live
# as
# long
# as
# Ann PERSON
# Nixon PERSON
# Cooper PERSON
# ,
# what
# change
# will
# they
# see
# ?
# What
# progress
# will
# we
# have
# made
# ?
#
#
# This
# is
# our
# chance
# to
# answer
# that
# call
# .
# This
# is
# our
# moment
# .
#
#
# This
# is
# our
# time
# ,
# to
# put
# our
# people
# back
# to
# work
# and
# open
# doors
# of
# opportunity
# for
# our
# kids
# ;
# to
# restore
# prosperity
# and
# promote
# the
# cause
# of
# peace
# ;
# to
# reclaim
# the
# American NORP
# dream
# and
# reaffirm
# that
# fundamental
# truth
# ,
# that
# ,
# out
# of
# many
# ,
# we
# are
# one
# ;
# that
# while
# we
# breathe
# ,
# we
# hope
# .
# And
# where
# we
# are
# met
# with
# cynicism
# and
# doubts
# and
# those
# who
# tell
# us
# that
# we
# ca
# n’t
# ,
# we
# will
# respond
# with
# that
# timeless
# creed
# that
# sums
# up
# the
# spirit
# of
# a
# people
# :
# Yes
# ,
# we
# can
# .
# [
# Chicago GPE
# America GPE
# tonight TIME
# three hours TIME
# four hours TIME
# first ORDINAL
# Democrat NORP
# Republican NORP
# Hispanic NORP
# Asian NORP
# Native American NORP
# Americans NORP
# the United States of America GPE
# tonight TIME
# America GPE
# Washington GPE
# Des Moines GPE
# Concord GPE
# Charleston GPE
# $5 and $10 and $20 MONEY
# millions CARDINAL
# Americans NORP
# more than two centuries later DATE
# Earth LOC
# tonight TIME
# tomorrow DATE
# two CARDINAL
# a century DATE
# tonight TIME
# Americans NORP
# Iraq GPE
# Afghanistan GPE
# one year DATE
# one CARDINAL
# America GPE
# tonight TIME
# America GPE
# 221 years DATE
# 21 months ago DATE
# winter DATE
# this autumn night TIME
# Main Street FAC
# one CARDINAL
# one CARDINAL
# first ORDINAL
# the Republican Party ORG
# the White House ORG
# the Democratic Party ORG
# tonight TIME
# Lincoln ORG
# Americans NORP
# tonight TIME
# tonight TIME
# American NORP
# America GPE
# Tonight TIME
# America GPE
# America GPE
# tomorrow DATE
# tonight TIME
# Atlanta GPE
# millions CARDINAL
# one CARDINAL
# Ann Nixon Cooper PERSON
# 106 years old DATE
# two CARDINAL
# tonight TIME
# America GPE
# American NORP
# Montgomery ORG
# Birmingham GPE
# Selma GPE
# Atlanta GPE
# the moon LOC
# Berlin GPE
# this year DATE
# 106 years DATE
# America GPE
# hours TIME
# America GPE
# America GPE
# tonight TIME
# the next century DATE
# Ann Nixon Cooper PERSON
# American NORP

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>
#
# El token que contiene la etiqueta NER es el atributo ent_type_.
#
# También se puede obtener la etiqueta NER usando la lista de entidades del texto, que se puede obtener con doc.ents. En este caso, se obtiene el texto y la etiqueta NER de cada entidad. Este segundo método solo pintara los tokens que tengan una etiqueta NER.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 7.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Qué entidades soporta Spacy?, ¿Qué significa cada una?</span>
#
# <b>Nota</b>: Debes escribir el código que liste las entidades disponibles y la explicación de las mismas. El listado sin código se considerará respuesta incompleta.

# %%
# Incluye aquí el código generado para poder responder a tu pregunta

for ent in nlp.get_pipe("ner").labels:
    print(ent)
    print(spacy.explain(ent))
# Out:
# CARDINAL
# Numerals that do not fall under another type
# DATE
# Absolute or relative dates or periods
# EVENT
# Named hurricanes, battles, wars, sports events, etc.
# FAC
# Buildings, airports, highways, bridges, etc.
# GPE
# Countries, cities, states
# LANGUAGE
# Any named language
# LAW
# Named documents made into laws.
# LOC
# Non-GPE locations, mountain ranges, bodies of water
# MONEY
# Monetary values, including unit
# NORP
# Nationalities or religious or political groups
# ORDINAL
# "first", "second", etc.
# ORG
# Companies, agencies, institutions, etc.
# PERCENT
# Percentage, including "%"
# PERSON
# People, including fictional
# PRODUCT
# Objects, vehicles, foods, etc. (not services)
# QUANTITY
# Measurements, as of weight or distance
# TIME
# Times smaller than a day
# WORK_OF_ART
# Titles of books, songs, etc.

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>
#
# Obtenemos la lista por defecto de entidades soportadas por Spacy, que se obtiene con:
# ```
# nlp.get_pipe("ner").labels
# ```
# Para cada entidad, se obtiene la descripción que proporciona Spacy, con el explain

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 8.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Qué entidades diferentes son reconocidas en el texto?, ¿cuántas hay de cada tipo?</span>

# %%
uniqueEntities = []
for entity in doc.ents:
    if not entity.label_ in uniqueEntities:
        uniqueEntities.append(entity.label_)
print(uniqueEntities)

for entity in uniqueEntities:
    print(entity, len([ent for ent in doc.ents if ent.label_ == entity]))
# Out:
# ['GPE', 'TIME', 'ORDINAL', 'NORP', 'MONEY', 'CARDINAL', 'DATE', 'LOC', 'FAC', 'ORG', 'PERSON']
# GPE 24
# TIME 16
# ORDINAL 2
# NORP 12
# MONEY 1
# CARDINAL 8
# DATE 12
# LOC 2
# FAC 1
# ORG 5
# PERSON 2

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>
#
# Primero, creo una lista de entidades únicas, recorriendo todas las entidades del documento, y añadiendo las que no están.
# A continuación, recorro la lista de entidades únicas y obtengo el número de entidades de cada tipo.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 9.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Explica con tus palabras qué es el código IOB para el reconocimiento de entiedades. Pon un ejemplo, sacado del texto, de una etiqueta de un único token y una etiqueta compuesta por varios tokens.</span>

# %%
etiquetas_iob = [(ent.text, ent.start_char, ent.end_char, ent.label_) for ent in doc.ents]

# Imprimir las etiquetas IOB
for etiqueta in etiquetas_iob:
    print(etiqueta)
# Out:
# ('Chicago', 8, 15, 'GPE')
# ('America', 68, 75, 'GPE')
# ('tonight', 235, 242, 'TIME')
# ('three hours', 392, 403, 'TIME')
# ('four hours', 408, 418, 'TIME')
# ('first', 433, 438, 'ORDINAL')
# ('Democrat', 616, 624, 'NORP')
# ('Republican', 629, 639, 'NORP')
# ('Hispanic', 655, 663, 'NORP')
# ('Asian', 665, 670, 'NORP')
# ('Native American', 672, 687, 'NORP')
# ('Americans', 731, 740, 'NORP')
# ('the United States of America', 905, 933, 'GPE')
# ('tonight', 1201, 1208, 'TIME')
# ('America', 1306, 1313, 'GPE')
# ('Washington', 1427, 1437, 'GPE')
# ('Des Moines', 1468, 1478, 'GPE')
# ('Concord', 1503, 1510, 'GPE')
# ('Charleston', 1536, 1546, 'GPE')
# ('$5 and $10 and $20', 1636, 1654, 'MONEY')
# ('millions', 1993, 2001, 'CARDINAL')
# ('Americans', 2005, 2014, 'NORP')
# ('more than two centuries later', 2061, 2090, 'DATE')
# ('Earth', 2179, 2184, 'LOC')
# ('tonight', 2400, 2407, 'TIME')
# ('tomorrow', 2437, 2445, 'DATE')
# ('two', 2492, 2495, 'CARDINAL')
# ('a century', 2551, 2560, 'DATE')
# ('tonight', 2584, 2591, 'TIME')
# ('Americans', 2617, 2626, 'NORP')
# ('Iraq', 2655, 2659, 'GPE')
# ('Afghanistan', 2681, 2692, 'GPE')
# ('one year', 3119, 3127, 'DATE')
# ('one', 3139, 3142, 'CARDINAL')
# ('America', 3154, 3161, 'GPE')
# ('tonight', 3204, 3211, 'TIME')
# ('America', 3684, 3691, 'GPE')
# ('221 years', 3696, 3705, 'DATE')
# ('21 months ago', 3785, 3798, 'DATE')
# ('winter', 3816, 3822, 'DATE')
# ('this autumn night', 3837, 3854, 'TIME')
# ('Main Street', 4391, 4402, 'FAC')
# ('one', 4448, 4451, 'CARDINAL')
# ('one', 4463, 4466, 'CARDINAL')
# ('first', 4667, 4672, 'ORDINAL')
# ('the Republican Party', 4695, 4715, 'ORG')
# ('the White House', 4719, 4734, 'ORG')
# ('the Democratic Party', 4872, 4892, 'ORG')
# ('tonight', 4917, 4924, 'TIME')
# ('Lincoln', 5037, 5044, 'ORG')
# ('Americans', 5211, 5220, 'NORP')
# ('tonight', 5284, 5291, 'TIME')
# ('tonight', 5396, 5403, 'TIME')
# ('American', 5607, 5615, 'NORP')
# ('America', 5802, 5809, 'GPE')
# ('Tonight', 5842, 5849, 'TIME')
# ('America', 6094, 6101, 'GPE')
# ('America', 6108, 6115, 'GPE')
# ('tomorrow', 6231, 6239, 'DATE')
# ('tonight', 6349, 6356, 'TIME')
# ('Atlanta', 6396, 6403, 'GPE')
# ('millions', 6426, 6434, 'CARDINAL')
# ('one', 6517, 6520, 'CARDINAL')
# ('Ann Nixon Cooper', 6528, 6544, 'PERSON')
# ('106 years old', 6548, 6561, 'DATE')
# ('two', 6713, 6716, 'CARDINAL')
# ('tonight', 6793, 6800, 'TIME')
# ('America', 6862, 6869, 'GPE')
# ('American', 7009, 7017, 'NORP')
# ('Montgomery', 7564, 7574, 'ORG')
# ('Birmingham', 7589, 7599, 'GPE')
# ('Selma', 7613, 7618, 'GPE')
# ('Atlanta', 7640, 7647, 'GPE')
# ('the moon', 7726, 7734, 'LOC')
# ('Berlin', 7756, 7762, 'GPE')
# ('this year', 7826, 7835, 'DATE')
# ('106 years', 7924, 7933, 'DATE')
# ('America', 7937, 7944, 'GPE')
# ('hours', 7991, 7996, 'TIME')
# ('America', 8012, 8019, 'GPE')
# ('America', 8044, 8051, 'GPE')
# ('tonight', 8132, 8139, 'TIME')
# ('the next century', 8199, 8215, 'DATE')
# ('Ann Nixon Cooper', 8271, 8287, 'PERSON')
# ('American', 8571, 8579, 'NORP')

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>
#
# El código IOB (Inside-Outside-Beginning) se utiliza para identificar las entidades en un texto, se utiliza para indicar si una palabra es el inicio, el interior o el exterior de una entidad. El código IOB se utiliza sobre todo en tareas como la identificación de nombres de personas, lugares o cosas.
#
# De la lista de arriba, podemos ver los siguientes ejemplos:
# 1 token: "Chicago", "America", "tonight", "hours", etc...
# más de un token: "the moon", "106 years old", "the Republican Party", "the White House", "more than two centuries later", etc.....

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 10.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Cuántas palabras tiene el texto?</span>

# %%
# Incluye aquí el código generado para poder responder a tu pregunta

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>
